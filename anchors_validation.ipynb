# %% [markdown]
# # **Anchors**

# %%
pip install anchor-exp
# Out:
# 9647.92s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: anchor-exp in ./.venv/lib/python3.11/site-packages (0.0.2.0)
# Requirement already satisfied: numpy in ./.venv/lib/python3.11/site-packages (from anchor-exp) (1.24.1)
# Requirement already satisfied: scipy in ./.venv/lib/python3.11/site-packages (from anchor-exp) (1.10.0)
# Requirement already satisfied: spacy in ./.venv/lib/python3.11/site-packages (from anchor-exp) (3.8.5)
# Requirement already satisfied: lime in ./.venv/lib/python3.11/site-packages (from anchor-exp) (0.2.0.1)
# Requirement already satisfied: scikit-learn>=0.22 in ./.venv/lib/python3.11/site-packages (from anchor-exp) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in ./.venv/lib/python3.11/site-packages (from scikit-learn>=0.22->anchor-exp) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.venv/lib/python3.11/site-packages (from scikit-learn>=0.22->anchor-exp) (3.6.0)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.11/site-packages (from lime->anchor-exp) (3.6.3)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.11/site-packages (from lime->anchor-exp) (4.67.1)
# Requirement already satisfied: scikit-image>=0.12 in ./.venv/lib/python3.11/site-packages (from lime->anchor-exp) (0.24.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in ./.venv/lib/python3.11/site-packages (from spacy->anchor-exp) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in ./.venv/lib/python3.11/site-packages (from spacy->anchor-exp) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in ./.venv/lib/python3.11/site-packages (from spacy->anchor-exp) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in ./.venv/lib/python3.11/site-packages (from spacy->anchor-exp) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in ./.venv/lib/python3.11/site-packages (from spacy->anchor-exp) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in ./.venv/lib/python3.11/site-packages (from spacy->anchor-exp) (8.3.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in ./.venv/lib/python3.11/site-packages (from spacy->anchor-exp) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in ./.venv/lib/python3.11/site-packages (from spacy->anchor-exp) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in ./.venv/lib/python3.11/site-packages (from spacy->anchor-exp) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in ./.venv/lib/python3.11/site-packages (from spacy->anchor-exp) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in ./.venv/lib/python3.11/site-packages (from spacy->anchor-exp) (0.15.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in ./.venv/lib/python3.11/site-packages (from spacy->anchor-exp) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in ./.venv/lib/python3.11/site-packages (from spacy->anchor-exp) (2.11.3)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.11/site-packages (from spacy->anchor-exp) (3.1.6)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.11/site-packages (from spacy->anchor-exp) (78.1.0)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.11/site-packages (from spacy->anchor-exp) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in ./.venv/lib/python3.11/site-packages (from spacy->anchor-exp) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in ./.venv/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy->anchor-exp) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->anchor-exp) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in ./.venv/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->anchor-exp) (2.33.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in ./.venv/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->anchor-exp) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./.venv/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->anchor-exp) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy->anchor-exp) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy->anchor-exp) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy->anchor-exp) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy->anchor-exp) (2025.1.31)
# Requirement already satisfied: networkx>=2.8 in ./.venv/lib/python3.11/site-packages (from scikit-image>=0.12->lime->anchor-exp) (3.4.2)
# Requirement already satisfied: pillow>=9.1 in ./.venv/lib/python3.11/site-packages (from scikit-image>=0.12->lime->anchor-exp) (11.2.1)
# Requirement already satisfied: imageio>=2.33 in ./.venv/lib/python3.11/site-packages (from scikit-image>=0.12->lime->anchor-exp) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in ./.venv/lib/python3.11/site-packages (from scikit-image>=0.12->lime->anchor-exp) (2025.3.30)
# Requirement already satisfied: lazy-loader>=0.4 in ./.venv/lib/python3.11/site-packages (from scikit-image>=0.12->lime->anchor-exp) (0.4)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in ./.venv/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.4->spacy->anchor-exp) (1.2.1)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in ./.venv/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.4->spacy->anchor-exp) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in ./.venv/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy->anchor-exp) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in ./.venv/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy->anchor-exp) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in ./.venv/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy->anchor-exp) (14.0.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in ./.venv/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy->anchor-exp) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in ./.venv/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy->anchor-exp) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.11/site-packages (from jinja2->spacy->anchor-exp) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.11/site-packages (from matplotlib->lime->anchor-exp) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.11/site-packages (from matplotlib->lime->anchor-exp) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.11/site-packages (from matplotlib->lime->anchor-exp) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./.venv/lib/python3.11/site-packages (from matplotlib->lime->anchor-exp) (1.4.8)
# Requirement already satisfied: pyparsing>=2.2.1 in ./.venv/lib/python3.11/site-packages (from matplotlib->lime->anchor-exp) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.11/site-packages (from matplotlib->lime->anchor-exp) (2.9.0.post0)
# Requirement already satisfied: marisa-trie>=1.1.0 in ./.venv/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy->anchor-exp) (1.2.1)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->lime->anchor-exp) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy->anchor-exp) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy->anchor-exp) (2.19.1)
# Requirement already satisfied: wrapt in ./.venv/lib/python3.11/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy->anchor-exp) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy->anchor-exp) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from __future__ import print_function
import numpy as np
np.random.seed(1)
import sys
import sklearn
import sklearn.ensemble
# %load_ext autoreload
# %autoreload 2
from anchor import utils
from anchor import anchor_tabular
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# **Define the datasets**

# %%
training_folder = 'datasets/dataset5000.csv'
validation_folder = 'datasets/dataset500.csv'


training_df = pd.read_csv(training_folder)
validation_df = pd.read_csv(validation_folder)

# take only the values that are true for all the requirements and drop only the requirements columns
all_true_training_dataset = training_df[(training_df['req_0'] == 1) & (training_df['req_1'] == 1) & (training_df['req_2'] == 1) & (training_df['req_3'] == 1)]
all_true_training_dataset = all_true_training_dataset.drop(columns=['req_0','req_1', 'req_2', 'req_3'])

req_names = ['req_0', 'req_1', 'req_2', 'req_3']
feature_names = ['cruise speed','image resolution','illuminance','controls responsiveness','power','smoke intensity','obstacle size','obstacle distance','firm obstacle']

# %% [markdown]
# **Train the model and the anchors**

# %%
models = [] #will contain the models (one per requirement)
datasets = [] #will contain the datasets as needed by the anchor library

explanations = np.zeros((len(req_names), all_true_training_dataset.shape[0]), dtype=object) #will contain the explanations (objects)
exp_txt = [] #will contain the textual explanations its structure is a matrix (list of lists) where each row corresponds to a requirement 
             #and each column corresponds to the explanation for the corresponding row in all_true_training_dataset

feature_to_use = [i for i in range(9)] #contains the range of features to use

for i in range(len(req_names)):
    
    #we load the dataset in anchors
    datasets.append(\
        utils.load_csv_dataset(\
            training_folder, 9+i,\
            features_to_use=feature_to_use,\
            categorical_features=None))
    
    #initialize and train the model
    models.append(\
        sklearn.ensemble.GradientBoostingClassifier(random_state=1234))
    models[i].fit(datasets[i].train, datasets[i].labels_train)

    #initialize the explainer
    explainer = anchor_tabular.AnchorTabularExplainer(
        datasets[i].class_names, #it maps the 0 and 1 in the dataset's requirements to the class names
        datasets[i].feature_names,
        datasets[i].train,
        datasets[i].categorical_names)
    
    #explain only points satisfying all the requirements
    names = []
    
    for j in range(all_true_training_dataset.shape[0]):
        exp = explainer.explain_instance(all_true_training_dataset.iloc[j].values.reshape(1, -1), models[i].predict, threshold=0.95)
        explanations[i,j] = exp
        names.append(exp.names())
        
    
    exp_txt.append(names)
    
    print(exp_txt[i])
# Out:
# [["b'firm obstacle' = 1.0", "b'image resolution' > 49.80", "b'cruise speed' <= 75.49", "b'smoke intensity' <= 23.42", "b'illuminance' > 26.13", "b'power' > 25.00", "b'obstacle distance' <= 74.78"], ["b'firm obstacle' = 1.0", "b'illuminance' > 50.87", "b'image resolution' > 25.40", "b'cruise speed' <= 75.49", "b'smoke intensity' <= 73.67", "b'power' > 25.00", "b'obstacle size' > 50.25"], ["b'image resolution' <= 25.40", "b'smoke intensity' > 73.67"], ["b'firm obstacle' = 1.0", "b'image resolution' > 49.80", "b'illuminance' > 26.13", "b'cruise speed' <= 75.49", "b'smoke intensity' <= 48.87", "b'power' > 51.00", "b'obstacle size' > 26.74"], ["b'firm obstacle' = 1.0", "b'image resolution' > 75.24", "b'smoke intensity' <= 48.87", "b'illuminance' > 75.91", "b'cruise speed' <= 75.49", "b'obstacle size' > 50.25", "b'obstacle distance' <= 49.94"], ["b'firm obstacle' = 1.0", "b'image resolution' > 49.80", "b'illuminance' > 50.87", "50.17 < b'cruise speed' <= 75.49", "b'obstacle size' > 74.61", "25.00 < b'power' <= 51.00", "b'obstacle distance' <= 74.78"], ["b'firm obstacle' = 1.0", "b'image resolution' > 75.24", "b'illuminance' > 26.13", "b'smoke intensity' <= 23.42", "b'cruise speed' <= 25.21", "b'obstacle distance' <= 74.78", "b'power' > 25.00"], ["b'firm obstacle' = 1.0", "b'smoke intensity' <= 48.87", "25.21 < b'cruise speed' <= 50.17", "b'image resolution' > 25.40", "b'obstacle size' > 26.74", "b'obstacle distance' <= 49.94", "b'power' > 51.00", "b'controls responsiveness' > 26.39"], ["b'firm obstacle' = 1.0", "b'illuminance' > 50.87", "b'image resolution' > 75.24", "b'cruise speed' <= 50.17", "b'smoke intensity' <= 73.67", "b'power' > 51.00", "b'obstacle distance' <= 49.94"], ["b'firm obstacle' = 1.0", "b'image resolution' > 75.24", "b'illuminance' > 50.87", "b'cruise speed' <= 25.21", "b'smoke intensity' <= 73.67", "b'obstacle size' > 50.25", "b'obstacle distance' <= 74.78"], ["b'firm obstacle' = 1.0", "b'image resolution' > 49.80", "b'cruise speed' <= 50.17", "b'illuminance' > 26.13", "b'smoke intensity' <= 23.42", "b'obstacle size' > 50.25", "b'power' > 51.00"], ["b'firm obstacle' = 1.0", "b'image resolution' > 49.80", "b'illuminance' > 50.87", "b'cruise speed' <= 75.49", "b'smoke intensity' <= 48.87", "b'power' > 51.00", "b'obstacle distance' <= 74.78"], ["b'firm obstacle' = 1.0", "b'illuminance' > 50.87", "b'image resolution' > 49.80", "b'cruise speed' <= 50.17", "b'smoke intensity' <= 73.67", "b'obstacle size' > 74.61", "b'obstacle distance' <= 25.34"], ["b'cruise speed' <= 50.17", "b'image resolution' > 49.80", "b'illuminance' > 50.87", "b'smoke intensity' <= 73.67", "b'obstacle distance' <= 49.94", "b'obstacle size' > 26.74", "b'power' > 51.00"], ["b'firm obstacle' = 1.0", "49.80 < b'image resolution' <= 75.24", "b'illuminance' > 75.91", "b'cruise speed' <= 75.49", "b'obstacle size' > 26.74", "b'obstacle distance' <= 74.78", "b'power' > 25.00"], ["b'firm obstacle' = 1.0", "b'image resolution' > 49.80", "b'illuminance' > 50.87", "b'smoke intensity' <= 48.87", "b'cruise speed' <= 75.49", "b'obstacle size' > 50.25", "b'power' > 76.00"], ["b'firm obstacle' = 1.0", "b'illuminance' > 50.87", "b'image resolution' > 75.24", "b'smoke intensity' <= 73.67", "b'cruise speed' <= 75.49", "b'obstacle size' > 26.74", "b'power' > 25.00"], ["b'firm obstacle' = 1.0", "b'image resolution' > 49.80", "b'illuminance' > 26.13", "b'cruise speed' <= 50.17", "b'smoke intensity' <= 48.87", "b'power' > 25.00", "b'obstacle distance' <= 25.34"], ["b'cruise speed' <= 25.21", "b'smoke intensity' <= 48.87", "b'illuminance' > 50.87", "b'image resolution' > 25.40", "b'obstacle size' > 26.74", "b'power' > 51.00", "b'obstacle distance' <= 74.78"], ["b'firm obstacle' = 1.0", "b'smoke intensity' <= 23.42", "b'illuminance' > 75.91", "25.40 < b'image resolution' <= 49.80", "b'cruise speed' <= 25.21", "26.74 < b'obstacle size' <= 50.25"], ["b'firm obstacle' = 1.0", "b'smoke intensity' <= 23.42", "26.13 < b'illuminance' <= 75.91", "50.17 < b'cruise speed' <= 75.49", ...
# [["b'firm obstacle' = 1.0"], ["b'controls responsiveness' <= 26.39"], ["b'firm obstacle' = 1.0"], ["b'firm obstacle' = 1.0"], ["b'firm obstacle' = 1.0"], ["b'firm obstacle' = 1.0"], ["b'cruise speed' <= 25.21", "b'controls responsiveness' > 50.29", "b'image resolution' > 75.24", "b'illuminance' > 26.13", "b'smoke intensity' <= 23.42", "b'power' > 51.00", "b'obstacle distance' <= 74.78", "26.74 < b'obstacle size' <= 74.61"], ["b'firm obstacle' = 1.0"], ["b'firm obstacle' = 1.0"], ["b'firm obstacle' = 1.0"], ["b'firm obstacle' = 1.0"], ["b'firm obstacle' = 1.0"], ["b'cruise speed' <= 25.21", "b'controls responsiveness' > 73.90", "b'illuminance' > 75.91", "b'image resolution' > 75.24", "b'smoke intensity' <= 48.87", "b'power' > 25.00", "b'obstacle distance' <= 74.78", "b'obstacle size' > 74.61"], ["b'firm obstacle' = 0.0", "b'cruise speed' <= 25.21", "b'controls responsiveness' > 26.39", "b'illuminance' > 50.87", "49.80 < b'image resolution' <= 75.24", "23.42 < b'smoke intensity' <= 73.67", "b'power' > 51.00", "b'obstacle distance' <= 74.78", "26.74 < b'obstacle size' <= 50.25"], ["b'firm obstacle' = 1.0"], ["b'firm obstacle' = 1.0"], ["b'firm obstacle' = 1.0"], ["b'firm obstacle' = 1.0"], ["b'firm obstacle' = 0.0", "b'cruise speed' <= 50.17", "b'controls responsiveness' > 50.29", "b'illuminance' > 50.87", "b'image resolution' > 25.40", "25.34 < b'obstacle distance' <= 74.78", "b'power' > 76.00"], ["b'cruise speed' <= 25.21", "b'controls responsiveness' > 73.90", "b'illuminance' > 75.91", "b'image resolution' > 25.40", "b'smoke intensity' <= 23.42", "b'obstacle distance' > 25.34", "26.74 < b'obstacle size' <= 50.25"], ["b'firm obstacle' = 1.0"], ["b'controls responsiveness' <= 26.39"], ["b'illuminance' > 50.87", "b'controls responsiveness' > 50.29", "b'cruise speed' <= 75.49", "b'image resolution' > 75.24", "b'smoke intensity' <= 23.42", "25.34 < b'obstacle distance' <= 49.94", "26.74 < b'obstacle size' <= 74.61"], ["b'firm obstacle' = 1.0"], ["b'firm obstacle' = 1.0"], ["b'firm obstacle' = 1.0"], ["b'firm obstacle' = 0.0", "b'cruise speed' <= 25.21", "b'controls responsiveness' > 50.29", "b'illuminance' > 26.13", "b'image resolution' > 25.40", "25.34 < b'obstacle distance' <= 74.78", "b'power' > 51.00"], ["b'cruise speed' <= 25.21", "b'controls responsiveness' > 73.90", "b'illuminance' > 75.91", "b'image resolution' > 75.24", "b'smoke intensity' <= 23.42", "b'power' > 51.00", "25.34 < b'obstacle distance' <= 49.94"], ["b'firm obstacle' = 1.0"], ["b'firm obstacle' = 1.0"], ["b'firm obstacle' = 1.0"], ["b'firm obstacle' = 0.0", "b'cruise speed' <= 50.17", "b'controls responsiveness' > 73.90", "b'illuminance' > 75.91", "b'image resolution' > 49.80", "25.34 < b'obstacle distance' <= 49.94", "b'power' > 25.00"], ["b'cruise speed' <= 25.21", "b'firm obstacle' = 0.0", "b'controls responsiveness' > 26.39", "b'illuminance' > 75.91", "b'image resolution' > 49.80", "48.87 < b'smoke intensity' <= 73.67", "b'power' > 25.00", "b'obstacle distance' > 25.34"], ["b'firm obstacle' = 0.0", "b'cruise speed' <= 50.17", "b'controls responsiveness' > 73.90", "b'illuminance' > 75.91", "b'image resolution' > 49.80", "b'power' > 25.00", "b'smoke intensity' <= 73.67", "b'obstacle distance' > 25.34"], ["b'firm obstacle' = 1.0"], ["b'firm obstacle' = 1.0"], ["b'firm obstacle' = 1.0"], ["b'firm obstacle' = 1.0"], ["b'firm obstacle' = 0.0", "b'controls responsiveness' > 73.90", "b'illuminance' > 75.91", "b'cruise speed' <= 75.49", "b'image resolution' > 49.80", "b'smoke intensity' <= 23.42", "b'power' > 25.00", "25.34 < b'obstacle distance' <= 74.78"], ["b'firm obstacle' = 1.0"], ["b'firm obstacle' = 1.0"], ["b'firm obstacle' = 1.0"], ["b'firm obstacle' = 1.0"], ["b'firm obstacle' = 1.0"], ["b'firm obstacle' = 1.0"], ["b'firm obstacle' = 1.0"], ["b'firm obstacle' = 0.0", "b'cruise speed' <= 25.21", "b'controls responsiveness' > 50.29", "b'illuminance' > 50.87", "b'image resolution' > 49.80", "25.34 < b'obstacle distance' <= 74.78", "b'power' > 25.00", "b'smok ...
# [["b'firm obstacle' = 1.0", "b'image resolution' > 49.80", "b'cruise speed' <= 50.17", "b'illuminance' > 26.13", "b'controls responsiveness' > 26.39", "b'obstacle size' <= 26.74", "b'power' > 25.00", "b'obstacle distance' > 25.34"], ["b'firm obstacle' = 1.0", "50.87 < b'illuminance' <= 75.91", "25.40 < b'image resolution' <= 75.24", "b'cruise speed' <= 75.49", "b'obstacle distance' > 25.34", "26.74 < b'obstacle size' <= 74.61", "b'power' > 25.00", "23.42 < b'smoke intensity' <= 73.67"], ["b'firm obstacle' = 1.0", "b'cruise speed' <= 25.21", "b'illuminance' > 75.91", "26.39 < b'controls responsiveness' <= 73.90", "49.94 < b'obstacle distance' <= 74.78", "25.00 < b'power' <= 51.00", "50.25 < b'obstacle size' <= 74.61"], ["b'firm obstacle' = 1.0", "b'image resolution' > 49.80", "b'controls responsiveness' > 73.90", "b'cruise speed' <= 75.49", "b'illuminance' > 50.87", "b'obstacle distance' > 49.94", "b'obstacle size' <= 50.25"], ["b'firm obstacle' = 1.0", "b'image resolution' > 49.80", "b'illuminance' > 75.91", "b'controls responsiveness' > 50.29", "b'cruise speed' <= 75.49", "b'obstacle distance' > 25.34", "b'obstacle size' <= 74.61"], ["b'firm obstacle' = 1.0", "b'image resolution' > 75.24", "b'illuminance' > 50.87", "b'cruise speed' <= 75.49", "b'controls responsiveness' > 50.29", "b'obstacle distance' > 49.94"], ["b'firm obstacle' = 1.0", "b'image resolution' > 75.24", "b'cruise speed' <= 25.21", "b'illuminance' > 26.13", "b'controls responsiveness' > 50.29", "b'power' > 25.00", "b'obstacle size' <= 74.61"], ["b'firm obstacle' = 1.0", "25.21 < b'cruise speed' <= 50.17", "50.29 < b'controls responsiveness' <= 73.90", "b'image resolution' > 25.40", "51.00 < b'power' <= 76.00", "b'obstacle distance' > 25.34", "26.74 < b'obstacle size' <= 74.61", "b'smoke intensity' <= 73.67"], ["b'firm obstacle' = 1.0", "b'image resolution' > 75.24", "b'illuminance' > 50.87", "b'cruise speed' <= 50.17", "b'controls responsiveness' > 26.39", "b'obstacle size' <= 50.25", "b'obstacle distance' > 25.34"], ["b'firm obstacle' = 1.0", "b'image resolution' > 75.24", "b'illuminance' > 50.87", "b'cruise speed' <= 25.21", "b'controls responsiveness' > 50.29", "b'power' > 25.00", "23.42 < b'smoke intensity' <= 73.67"], ["b'firm obstacle' = 1.0", "b'image resolution' > 49.80", "b'cruise speed' <= 50.17", "b'illuminance' > 50.87", "b'controls responsiveness' > 50.29", "b'obstacle distance' > 49.94"], ["b'firm obstacle' = 1.0", "b'image resolution' > 49.80", "b'cruise speed' <= 75.49", "b'illuminance' > 50.87", "b'controls responsiveness' > 26.39", "26.74 < b'obstacle size' <= 50.25", "b'power' > 76.00"], ["b'firm obstacle' = 1.0", "b'controls responsiveness' > 73.90", "b'cruise speed' <= 25.21", "b'image resolution' > 49.80", "b'illuminance' > 75.91", "b'smoke intensity' <= 48.87", "b'power' > 25.00"], ["b'firm obstacle' = 0.0"], ["b'firm obstacle' = 1.0", "b'image resolution' > 49.80", "b'illuminance' > 50.87", "b'controls responsiveness' > 73.90", "b'cruise speed' <= 75.49", "b'obstacle size' <= 50.25", "25.00 < b'power' <= 51.00"], ["b'firm obstacle' = 1.0", "b'image resolution' > 49.80", "b'cruise speed' <= 50.17", "b'illuminance' > 50.87", "b'obstacle distance' > 49.94", "26.74 < b'obstacle size' <= 74.61", "b'power' > 51.00", "b'smoke intensity' <= 48.87"], ["b'firm obstacle' = 1.0", "b'image resolution' > 75.24", "b'illuminance' > 50.87", "b'cruise speed' <= 75.49", "b'controls responsiveness' > 26.39", "b'obstacle distance' > 49.94", "b'obstacle size' <= 74.61"], ["b'firm obstacle' = 1.0", "b'image resolution' > 49.80", "b'cruise speed' <= 50.17", "b'controls responsiveness' > 73.90", "b'illuminance' > 26.13", "b'obstacle size' <= 50.25", "25.00 < b'power' <= 51.00"], ["b'firm obstacle' = 0.0"], ["b'firm obstacle' = 1.0", "b'controls responsiveness' > 73.90", "b'illuminance' > 50.87", "b'cruise speed' <= 75.49", "b'image resolution' > 25.40", "b'obstacle distance' > 49.94", "b'obstacle size' <= 74.61"], ["b'firm obstacle' = 1.0", "b'illuminance' > 50. ...
# [["b'firm obstacle' = 1.0", "b'image resolution' > 49.80", "b'cruise speed' <= 50.17", "b'illuminance' > 26.13", "b'controls responsiveness' > 26.39", "b'smoke intensity' <= 48.87", "b'obstacle distance' > 25.34", "b'obstacle size' <= 26.74"], ["b'firm obstacle' = 1.0", "50.87 < b'illuminance' <= 75.91", "25.40 < b'image resolution' <= 75.24", "b'cruise speed' <= 75.49", "23.42 < b'smoke intensity' <= 73.67", "51.00 < b'power' <= 76.00", "25.34 < b'obstacle distance' <= 49.94", "50.25 < b'obstacle size' <= 74.61"], ["b'firm obstacle' = 1.0", "b'illuminance' > 75.91", "b'cruise speed' <= 50.17", "b'controls responsiveness' > 26.39", "25.00 < b'power' <= 76.00", "25.34 < b'obstacle distance' <= 74.78", "b'obstacle size' <= 74.61"], ["b'firm obstacle' = 1.0", "b'image resolution' > 49.80", "b'controls responsiveness' > 73.90", "b'illuminance' > 26.13", "b'cruise speed' <= 75.49", "b'smoke intensity' <= 48.87", "b'obstacle distance' > 49.94"], ["b'firm obstacle' = 1.0", "b'image resolution' > 49.80", "b'controls responsiveness' > 50.29", "b'illuminance' > 75.91", "b'cruise speed' <= 75.49", "b'smoke intensity' <= 48.87", "b'obstacle distance' > 25.34"], ["b'firm obstacle' = 1.0", "b'image resolution' > 75.24", "50.87 < b'illuminance' <= 75.91", "b'cruise speed' <= 75.49", "b'controls responsiveness' > 50.29", "b'obstacle distance' > 49.94", "25.00 < b'power' <= 51.00"], ["b'firm obstacle' = 1.0", "b'image resolution' > 75.24", "b'controls responsiveness' > 26.39", "b'cruise speed' <= 75.49", "b'illuminance' > 26.13", "b'smoke intensity' <= 48.87", "b'obstacle size' <= 74.61", "b'power' > 25.00"], ["b'firm obstacle' = 1.0", "25.40 < b'image resolution' <= 75.24", "25.21 < b'cruise speed' <= 50.17", "50.29 < b'controls responsiveness' <= 73.90", "25.34 < b'obstacle distance' <= 74.78", "25.00 < b'power' <= 76.00", "b'smoke intensity' <= 48.87", "b'obstacle size' <= 50.25"], ["b'firm obstacle' = 1.0", "b'image resolution' > 75.24", "b'cruise speed' <= 50.17", "b'illuminance' > 50.87", "b'controls responsiveness' > 26.39", "b'obstacle size' <= 50.25", "b'obstacle distance' > 25.34"], ["b'firm obstacle' = 1.0", "b'image resolution' > 75.24", "b'illuminance' > 50.87", "b'controls responsiveness' > 50.29", "b'cruise speed' <= 50.17", "23.42 < b'smoke intensity' <= 73.67", "25.00 < b'power' <= 51.00"], ["b'firm obstacle' = 1.0", "b'image resolution' > 49.80", "b'controls responsiveness' > 50.29", "b'illuminance' > 50.87", "b'cruise speed' <= 75.49", "b'smoke intensity' <= 48.87", "b'obstacle distance' > 25.34"], ["b'firm obstacle' = 1.0", "b'image resolution' > 49.80", "b'illuminance' > 50.87", "b'controls responsiveness' > 26.39", "b'cruise speed' <= 75.49", "b'smoke intensity' <= 48.87", "b'obstacle size' <= 50.25", "b'power' > 51.00"], ["b'firm obstacle' = 1.0", "b'image resolution' > 49.80", "b'controls responsiveness' > 73.90", "b'illuminance' > 75.91", "b'cruise speed' <= 25.21", "23.42 < b'smoke intensity' <= 73.67"], ["b'firm obstacle' = 0.0"], ["b'firm obstacle' = 1.0", "b'controls responsiveness' > 73.90", "b'illuminance' > 50.87", "49.80 < b'image resolution' <= 75.24", "b'cruise speed' <= 75.49", "26.74 < b'obstacle size' <= 50.25", "25.00 < b'power' <= 51.00"], ["b'firm obstacle' = 1.0", "b'image resolution' > 49.80", "b'cruise speed' <= 50.17", "b'illuminance' > 26.13", "23.42 < b'smoke intensity' <= 73.67", "b'power' > 25.00", "b'obstacle distance' > 49.94", "50.25 < b'obstacle size' <= 74.61"], ["b'firm obstacle' = 1.0", "b'image resolution' > 75.24", "b'cruise speed' <= 75.49", "b'controls responsiveness' > 26.39", "b'illuminance' > 75.91", "b'smoke intensity' <= 23.42", "b'obstacle distance' > 49.94"], ["b'firm obstacle' = 1.0", "b'image resolution' > 49.80", "b'controls responsiveness' > 73.90", "b'cruise speed' <= 50.17", "b'illuminance' > 26.13", "23.42 < b'smoke intensity' <= 73.67", "b'obstacle size' <= 74.61"], ["b'firm obstacle' = 0.0"], ["b'firm obstacle' = 1.0", "b'controls responsiveness' > 73.90", "b'image res ...

# %% [markdown]
# **Let us make some checks...**

# %%
np.count_nonzero(explanations[0] == explanations[1]) #count the number of times the explanations are the same for the two requirements
# Out:
# 0

# %%
len(exp_txt), len(exp_txt[0])
# Out:
# (4, 205)

# %% [markdown]
# **Define useful data-wrangling functions**

# %% [markdown]
# function separating the name of the feature from the ranges

# %%
def get_anchor(a):
    quoted_part = a.split("'")[1]
    rest = a.replace(f"'{quoted_part}'", '').replace("b", '').strip()

    return quoted_part, rest

# %% [markdown]
# function creating the intervals

# %%
import re
from math import inf

def parse_range(expr: str):
    expr = expr.strip().replace(" ", "")
    
    patterns = [
        (r"^=(\-?\d+(\.\d+)?)$", 'equals'),
        (r"^(>=|>)\s*(-?\d+(\.\d+)?)$", 'lower'),
        (r"^(<=|<)\s*(-?\d+(\.\d+)?)$", 'upper'),
        (r"^(-?\d+(\.\d+)?)(<=|<){1,2}(<=|<)(-?\d+(\.\d+)?)$", 'between'),
        (r"^(-?\d+(\.\d+)?)(>=|>){1,2}(>=|>)(-?\d+(\.\d+)?)$", 'reverse_between'),
    ]
    
    for pattern, kind in patterns:
        match = re.match(pattern, expr)
        if match:
            if kind == 'equals':
                num = float(match.group(1))
                return (num, num, True, True)
            elif kind == 'lower':
                op, num = match.group(1), float(match.group(2))
                return (
                    num,
                    inf,
                    op == '>=',
                    False
                )
            elif kind == 'upper':
                op, num = match.group(1), float(match.group(2))
                return (
                    -inf,
                    num,
                    False,
                    op == '<='
                )
            elif kind == 'between':
                low = float(match.group(1))
                op1 = match.group(3)
                op2 = match.group(4)
                high = float(match.group(5))
                return (
                    low,
                    high,
                    op1 == '<=',
                    op2 == '<='
                )
            elif kind == 'reverse_between':
                high = float(match.group(1))
                op1 = match.group(3)
                op2 = match.group(4)
                low = float(match.group(5))
                return (
                    low,
                    high,
                    op2 == '>=',
                    op1 == '>='
                )

    raise ValueError(f"Unrecognized format: {expr}")

# %% [markdown]
# function that returns the interseption among two intervals

# %%
from typing import Optional, Tuple

def intersect(
    a: Tuple[float, float, bool, bool],
    b: Tuple[float, float, bool, bool]
) -> Optional[Tuple[float, float, bool, bool]]:
    
    a_low, a_high, a_li, a_ui = a
    b_low, b_high, b_li, b_ui = b

    # Compute max of lower bounds
    if a_low > b_low:
        low, li = a_low, a_li
    elif a_low < b_low:
        low, li = b_low, b_li
    else:
        low = a_low
        li = a_li and b_li

    # Compute min of upper bounds
    if a_high < b_high:
        high, ui = a_high, a_ui
    elif a_high > b_high:
        high, ui = b_high, b_ui
    else:
        high = a_high
        ui = a_ui and b_ui

    # Check for empty intersection
    if low > high:
        return None
    if low == high and not (li and ui):
        return None

    return (low, high, li, ui)

# %% [markdown]
# function that return the truth value of a num (val) being inside a given interval

# %%
def inside(val, interval):
    low, high, li, ui = interval
    if li and ui:
        return low <= val <= high
    elif li and not ui:
        return low <= val < high
    elif not li and ui:
        return low < val <= high
    else:
        return low < val < high

# %% [markdown]
# **Wrangle the data to cope better with them**
#
# Transform exp_txt in exp_dict a list of 4 dictionaries per element (one per requirement) in which are listed each feature with the respective constraints (as a range data structure)
# The range data structure is a 4-element tuple (float, float, boolean, boolean) where (a,b,x,y) num $\in$ (a,b) and x and y are true if the extremes are included, otherwise they are false

# %%
exp_dict =[]
for i in range(len(exp_txt[0])):
    exp_dict.append([{}, {}, {}, {}])
    for j in range(len(req_names)):
        for k in range(len(exp_txt[j][i])):
            quoted, rest = get_anchor(exp_txt[j][i][k])
            exp_dict[i][j][quoted] = parse_range(rest)

# %% [markdown]
# **Intersect all the obtained explanations over the different requirements**

# %%
exp_intersected = []

for i in range(len(exp_dict[0])):
    exp_intersected.append(exp_dict[i][3])
    for j in range(len(req_names)-1):
        for k in feature_names:
            if k in exp_dict[i][j]:
                if k in exp_intersected[i]:
                    inter = intersect(exp_dict[i][j][k], exp_intersected[i][k])
                    if inter is not None:
                        exp_intersected[i][k] = inter
                    else:
                        raise ValueError(f"Unrecognized format: {exp_dict[i][j][k]} and {exp_dict[i][j+1][k]}")
                else:
                    exp_intersected[i][k] = exp_dict[i][j][k]

# %% [markdown]
# # Validation

# %% [markdown]
# Define the function classifing w.r.t. the anchors

# %%
def classify_w_anchor(input, thresholds):
    inside_points = []

    featureNames = ['cruise speed','image resolution','illuminance','controls responsiveness','power',
     'smoke intensity','obstacle size','obstacle distance','firm obstacle']
    
    for i in range(input.shape[0]):
        for j in range(len(thresholds)):
            flag = True
            for k in featureNames:
                if k in thresholds[j]:
                    if not (inside(input.iloc[i][k], thresholds[j][k])):
                        flag = False
                        break
            if flag:
                inside_points.append(input.iloc[i])
                break
            else:
                flag = True
    return inside_points

# %% [markdown]
# Verify if the function works properly by submitting the whole 5k dataset, we should be obtaining only the previously obtained samples for which all the req. are satisfied

# %%
sat = []
for i in range(all_true_training_dataset.shape[0]):
    for j in range(len(exp_intersected)):
        flag = True
        for k in feature_names:
            if k not in exp_intersected[j]:
                continue
            else:
                if not (inside(all_true_training_dataset.iloc[i][k], exp_intersected[j][k])):
                    print(all_true_training_dataset.iloc[i])
                    flag = False
                    break
        
        if flag:
            sat.append(all_true_training_dataset.iloc[i])
            break
        else:
            flag = True
# Out:
# cruise speed               66.8818
# image resolution           34.0519
# illuminance                74.7470
# controls responsiveness    24.4433
# power                      72.0000
# smoke intensity            69.8451
# obstacle size              73.7317
# obstacle distance          28.6129
# firm obstacle               1.0000
# Name: 64, dtype: float64
# cruise speed               24.2402
# image resolution           24.1728
# illuminance                84.6850
# controls responsiveness    40.6126
# power                      49.0000
# smoke intensity            90.4350
# obstacle size              57.8777
# obstacle distance          56.5959
# firm obstacle               1.0000
# Name: 94, dtype: float64
# cruise speed               24.2402
# image resolution           24.1728
# illuminance                84.6850
# controls responsiveness    40.6126
# power                      49.0000
# smoke intensity            90.4350
# obstacle size              57.8777
# obstacle distance          56.5959
# firm obstacle               1.0000
# Name: 94, dtype: float64
# cruise speed               56.3059
# image resolution           69.7543
# illuminance                59.4607
# controls responsiveness    98.9978
# power                      61.0000
# smoke intensity            20.9066
# obstacle size              38.8309
# obstacle distance          80.6786
# firm obstacle               1.0000
# Name: 107, dtype: float64
# cruise speed               56.3059
# image resolution           69.7543
# illuminance                59.4607
# controls responsiveness    98.9978
# power                      61.0000
# smoke intensity            20.9066
# obstacle size              38.8309
# obstacle distance          80.6786
# firm obstacle               1.0000
# Name: 107, dtype: float64
# cruise speed               56.3059
# image resolution           69.7543
# illuminance                59.4607
# controls responsiveness    98.9978
# power                      61.0000
# smoke intensity            20.9066
# obstacle size              38.8309
# obstacle distance          80.6786
# firm obstacle               1.0000
# Name: 107, dtype: float64
# cruise speed               51.6897
# image resolution           90.8773
# illuminance                82.5221
# controls responsiveness    54.4592
# power                      46.0000
# smoke intensity            12.7199
# obstacle size              70.6452
# obstacle distance          32.3741
# firm obstacle               1.0000
# Name: 213, dtype: float64
# cruise speed               51.6897
# image resolution           90.8773
# illuminance                82.5221
# controls responsiveness    54.4592
# power                      46.0000
# smoke intensity            12.7199
# obstacle size              70.6452
# obstacle distance          32.3741
# firm obstacle               1.0000
# Name: 213, dtype: float64
# cruise speed               51.6897
# image resolution           90.8773
# illuminance                82.5221
# controls responsiveness    54.4592
# power                      46.0000
# smoke intensity            12.7199
# obstacle size              70.6452
# obstacle distance          32.3741
# firm obstacle               1.0000
# Name: 213, dtype: float64
# cruise speed               51.6897
# image resolution           90.8773
# illuminance                82.5221
# controls responsiveness    54.4592
# power                      46.0000
# smoke intensity            12.7199
# obstacle size              70.6452
# obstacle distance          32.3741
# firm obstacle               1.0000
# Name: 213, dtype: float64
# cruise speed               72.6772
# image resolution           80.8020
# illuminance                66.3604
# controls responsiveness    59.2346
# power                      31.0000
# smoke intensity            77.5366
# obstacle size              80.2404
# obstacle distance          71.9837
# firm obstacle               1.0000
# Name: 220, dtype: float64
# cruise speed               72.6772
# image resolution           80.8020
# illuminance                66.3604
# controls responsiveness    59.2346
# power                      31.0000
# smoke intensity            77.5366
# obstacle size              80.2404
# obstacle distance          71.9837
# firm obstacle               1.0000
# Name: 220, dtype: float64
# cruise speed               72.6772
# image resolution           80.8020
# illuminance                66.3604
# controls responsiveness    59.2346
# power                      31.0000
# smoke intensity            77.5366
# obstacle size              80.2404
# obstacle distance          71.9837
# firm obstacle               1.0000
# Name: 220, dtype: float64
# cruise speed               72.6772
# image resolution           80.8020
# illuminance                66.3604
# controls responsiveness    59.2346
# power                      31.0000
# smoke intensity            77.5366
# obstacle size              80.2404
# obstacle distance          71.9837
# firm obstacle               1.0000
# Name: 220, dtype: float64
# cruise speed                8.9868
# image resolution           79.1739
# illuminance                46.3701
# controls responsiveness    68.4400
# power                      76.0000
# smoke intensity            14.7732
# obstacle size              29.5136
# obstacle distance          21.9202
# firm obstacle               1.0000
# Name: 258, dtype: float64
# cruise speed                8.9868
# image resolution           79.1739
# illuminance                46.3701
# controls responsiveness    68.4400
# power                      76.0000
# smoke intensity            14.7732
# obstacle size              29.5136
# obstacle distance          21.9202
# firm obstacle               1.0000
# Name: 258, dtype: float64
# cruise speed                8.9868
# image resolution           79.1739
# illuminance                46.3701
# controls responsiveness    68.4400
# power                      76.0000
# smoke intensity            14.7732
# obstacle size              29.5136
# obstacle distance          21.9202
# firm obstacle               1.0000
# Name: 258, dtype: float64
# cruise speed                8.9868
# image resolution           79.1739
# illuminance                46.3701
# controls responsiveness    68.4400
# power                      76.0000
# smoke intensity            14.7732
# obstacle size              29.5136
# obstacle distance          21.9202
# firm obstacle               1.0000
# Name: 258, dtype: float64
# cruise speed               29.8882
# image resolution           39.5205
# illuminance                20.2007
# controls responsiveness    50.8366
# power                      73.0000
# smoke intensity            43.0800
# obstacle size              38.0193
# obstacle distance          27.7038
# firm obstacle               1.0000
# Name: 274, dtype: float64
# cruise speed               29.8882
# image resolution           39.5205
# illuminance                20.2007
# controls responsiveness    50.8366
# power                      73.0000
# smoke intensity            43.0800
# obstacle size              38.0193
# obstacle distance          27.7038
# firm obstacle               1.0000
# Name: 274, dtype: float64
# cruise speed               29.8882
# image resolution           39.5205
# illuminance                20.2007
# controls responsiveness    50.8366
# power                      73.0000
# smoke intensity            43.0800
# obstacle size              38.0193
# obstacle distance          27.7038
# firm obstacle               1.0000
# Name: 274, dtype: float64
# cruise speed               29.8882
# image resolution           39.5205
# illuminance                20.2007
# controls responsiveness    50.8366
# power                      73.0000
# smoke intensity            43.0800
# obstacle size              38.0193
# obstacle distance          27.7038
# firm obstacle               1.0000
# Name: 274, dtype: float64
# cruise speed               43.4908
# image resolution           80.4192
# illuminance                61.0144
# controls responsiveness    27.6345
# power                      63.0000
# smoke intensity            70.2171
# obstacle size              44.1055
# obstacle distance          37.3067
# firm obstacle               1.0000
# Name: 277, dtype: float64
# cruise speed               43.4908
# image resolution           80.4192
# illuminance                61.0144
# controls responsiveness    27.6345
# power                      63.0000
# smoke intensity            70.2171
# obstacle size              44.1055
# obstacle distance          37.3067
# firm obstacle               1.0000
# Name: 277, dtype: float64
# cruise speed               43.4908
# image resolution           80.4192
# illuminance                61.0144
# controls responsiveness    27.6345
# power                      63.0000
# smoke intensity            70.2171
# obstacle size              44.1055
# obstacle distance          37.3067
# firm obstacle               1.0000
# Name: 277, dtype: float64
# cruise speed               43.4908
# image resolution           80.4192
# illuminance                61.0144
# controls responsiveness    27.6345
# power                      63.0000
# smoke intensity            70.2171
# obstacle size              44.1055
# obstacle distance          37.3067
# firm obstacle               1.0000
# Name: 277, dtype: float64
# cruise speed                1.1317
# image resolution           88.6005
# illuminance                70.9674
# controls responsiveness    60.3758
# power                      46.0000
# smoke intensity            73.4505
# obstacle size              82.9409
# obstacle distance           9.6558
# firm obstacle               1.0000
# Name: 288, dtype: float64
# cruise speed                1.1317
# image resolution           88.6005
# illuminance                70.9674
# controls responsiveness    60.3758
# power                      46.0000
# smoke intensity            73.4505
# obstacle size              82.9409
# obstacle distance           9.6558
# firm obstacle               1.0000
# Name: 288, dtype: float64
# cruise speed                1.1317
# image resolution           88.6005
# illuminance                70.9674
# controls responsiveness    60.3758
# power                      46.0000
# smoke intensity            73.4505
# obstacle size              82.9409
# obstacle distance           9.6558
# firm obstacle               1.0000
# Name: 288, dtype: float64
# cruise speed                1.1317
# image resolution           88.6005
# illuminance                70.9674
# controls responsiveness    60.3758
# power                      46.0000
# smoke intensity            73.4505
# obstacle size              82.9409
# obstacle distance           9.6558
# firm obstacle               1.0000
# Name: 288, dtype: float64
# cruise speed               18.0456
# image resolution           65.7870
# illuminance                87.2935
# controls responsiveness    51.3124
# power                      76.0000
# smoke intensity            20.8091
# obstacle size              68.1416
# obstacle distance          54.5647
# firm obstacle               1.0000
# Name: 293, dtype: float64
# cruise speed               18.0456
# image resolution           65.7870
# illuminance                87.2935
# controls responsiveness    51.3124
# power                      76.0000
# smoke intensity            20.8091
# obstacle size              68.1416
# obstacle distance          54.5647
# firm obstacle               1.0000
# Name: 293, dtype: float64
# cruise speed               18.0456
# image resolution           65.7870
# illuminance                87.2935
# controls responsiveness    51.3124
# power                      76.0000
# smoke intensity            20.8091
# obstacle size              68.1416
# obstacle distance          54.5647
# firm obstacle               1.0000
# Name: 293, dtype: float64
# cruise speed               18.0456
# image resolution           65.7870
# illuminance                87.2935
# controls responsiveness    51.3124
# power                      76.0000
# smoke intensity            20.8091
# obstacle size              68.1416
# obstacle distance          54.5647
# firm obstacle               1.0000
# Name: 293, dtype: float64
# cruise speed               64.6561
# image resolution           68.9781
# illuminance                82.9255
# controls responsiveness    42.6201
# power                      85.0000
# smoke intensity            40.3172
# obstacle size              47.8115
# obstacle distance          19.4120
# firm obstacle               1.0000
# Name: 300, dtype: float64
# cruise speed               64.6561
# image resolution           68.9781
# illuminance                82.9255
# controls responsiveness    42.6201
# power                      85.0000
# smoke intensity            40.3172
# obstacle size              47.8115
# obstacle distance          19.4120
# firm obstacle               1.0000
# Name: 300, dtype: float64
# cruise speed               64.6561
# image resolution           68.9781
# illuminance                82.9255
# controls responsiveness    42.6201
# power                      85.0000
# smoke intensity            40.3172
# obstacle size              47.8115
# obstacle distance          19.4120
# firm obstacle               1.0000
# Name: 300, dtype: float64
# cruise speed               64.6561
# image resolution           68.9781
# illuminance                82.9255
# controls responsiveness    42.6201
# power                      85.0000
# smoke intensity            40.3172
# obstacle size              47.8115
# obstacle distance          19.4120
# firm obstacle               1.0000
# Name: 300, dtype: float64
# cruise speed                3.8123
# image resolution           86.4524
# illuminance                86.2598
# controls responsiveness    77.1327
# power                      45.0000
# smoke intensity            31.4196
# obstacle size              75.5068
# obstacle distance          20.9573
# firm obstacle               1.0000
# Name: 314, dtype: float64
# cruise speed                3.8123
# image resolution           86.4524
# illuminance                86.2598
# controls responsiveness    77.1327
# power                      45.0000
# smoke intensity            31.4196
# obstacle size              75.5068
# obstacle distance          20.9573
# firm obstacle               1.0000
# Name: 314, dtype: float64
# cruise speed                3.8123
# image resolution           86.4524
# illuminance                86.2598
# controls responsiveness    77.1327
# power                      45.0000
# smoke intensity            31.4196
# obstacle size              75.5068
# obstacle distance          20.9573
# firm obstacle               1.0000
# Name: 314, dtype: float64
# cruise speed                3.8123
# image resolution           86.4524
# illuminance                86.2598
# controls responsiveness    77.1327
# power                      45.0000
# smoke intensity            31.4196
# obstacle size              75.5068
# obstacle distance          20.9573
# firm obstacle               1.0000
# Name: 314, dtype: float64
# cruise speed               17.0347
# image resolution           68.7020
# illuminance                62.6728
# controls responsiveness    35.0663
# power                      56.0000
# smoke intensity            54.7225
# obstacle size              44.9043
# obstacle distance          18.8152
# firm obstacle               0.0000
# Name: 339, dtype: float64
# cruise speed               17.0347
# image resolution           68.7020
# illuminance                62.6728
# controls responsiveness    35.0663
# power                      56.0000
# smoke intensity            54.7225
# obstacle size              44.9043
# obstacle distance          18.8152
# firm obstacle               0.0000
# Name: 339, dtype: float64
# cruise speed               17.0347
# image resolution           68.7020
# illuminance                62.6728
# controls responsiveness    35.0663
# power                      56.0000
# smoke intensity            54.7225
# obstacle size              44.9043
# obstacle distance          18.8152
# firm obstacle               0.0000
# Name: 339, dtype: float64
# cruise speed               17.0347
# image resolution           68.7020
# illuminance                62.6728
# controls responsiveness    35.0663
# power                      56.0000
# smoke intensity            54.7225
# obstacle size              44.9043
# obstacle distance          18.8152
# firm obstacle               0.0000
# Name: 339, dtype: float64
# cruise speed               65.1537
# image resolution           61.3989
# illuminance                89.7247
# controls responsiveness    93.6795
# power                      31.0000
# smoke intensity            78.6409
# obstacle size              35.2961
# obstacle distance          25.0454
# firm obstacle               1.0000
# Name: 401, dtype: float64
# cruise speed               65.1537
# image resolution           61.3989
# illuminance                89.7247
# controls responsiveness    93.6795
# power                      31.0000
# smoke intensity            78.6409
# obstacle size              35.2961
# obstacle distance          25.0454
# firm obstacle               1.0000
# Name: 401, dtype: float64
# cruise speed               65.1537
# image resolution           61.3989
# illuminance                89.7247
# controls responsiveness    93.6795
# power                      31.0000
# smoke intensity            78.6409
# obstacle size              35.2961
# obstacle distance          25.0454
# firm obstacle               1.0000
# Name: 401, dtype: float64
# cruise speed               65.1537
# image resolution           61.3989
# illuminance                89.7247
# controls responsiveness    93.6795
# power                      31.0000
# smoke intensity            78.6409
# obstacle size              35.2961
# obstacle distance          25.0454
# firm obstacle               1.0000
# Name: 401, dtype: float64
# cruise speed               31.4432
# image resolution           79.3182
# illuminance                65.7700
# controls responsiveness    16.8945
# power                      95.0000
# smoke intensity            23.7921
# obstacle size              68.4129
# obstacle distance          52.6736
# firm obstacle               1.0000
# Name: 407, dtype: float64
# cruise speed               31.4432
# image resolution           79.3182
# illuminance                65.7700
# controls responsiveness    16.8945
# power                      95.0000
# smoke intensity            23.7921
# obstacle size              68.4129
# obstacle distance          52.6736
# firm obstacle               1.0000
# Name: 407, dtype: float64
# cruise speed               31.4432
# image resolution           79.3182
# illuminance                65.7700
# controls responsiveness    16.8945
# power                      95.0000
# smoke intensity            23.7921
# obstacle size              68.4129
# obstacle distance          52.6736
# firm obstacle               1.0000
# Name: 407, dtype: float64
# cruise speed               31.4432
# image resolution           79.3182
# illuminance                65.7700
# controls responsiveness    16.8945
# power                      95.0000
# smoke intensity            23.7921
# obstacle size              68.4129
# obstacle distance          52.6736
# firm obstacle               1.0000
# Name: 407, dtype: float64
# cruise speed               51.7177
# image resolution           90.4753
# illuminance                97.2046
# controls responsiveness    42.1691
# power                      76.0000
# smoke intensity            14.3367
# obstacle size              61.5630
# obstacle distance          60.6466
# firm obstacle               1.0000
# Name: 415, dtype: float64
# cruise speed               51.7177
# image resolution           90.4753
# illuminance                97.2046
# controls responsiveness    42.1691
# power                      76.0000
# smoke intensity            14.3367
# obstacle size              61.5630
# obstacle distance          60.6466
# firm obstacle               1.0000
# Name: 415, dtype: float64
# cruise speed               51.7177
# image resolution           90.4753
# illuminance                97.2046
# controls responsiveness    42.1691
# power                      76.0000
# smoke intensity            14.3367
# obstacle size              61.5630
# obstacle distance          60.6466
# firm obstacle               1.0000
# Name: 415, dtype: float64
# cruise speed               51.7177
# image resolution           90.4753
# illuminance                97.2046
# controls responsiveness    42.1691
# power                      76.0000
# smoke intensity            14.3367
# obstacle size              61.5630
# obstacle distance          60.6466
# firm obstacle               1.0000
# Name: 415, dtype: float64
# cruise speed               39.3790
# image resolution           67.1841
# illuminance                48.7692
# controls responsiveness    86.7376
# power                      31.0000
# smoke intensity            37.4754
# obstacle size               8.0487
# obstacle distance          20.5973
# firm obstacle               1.0000
# Name: 420, dtype: float64
# cruise speed               39.3790
# image resolution           67.1841
# illuminance                48.7692
# controls responsiveness    86.7376
# power                      31.0000
# smoke intensity            37.4754
# obstacle size               8.0487
# obstacle distance          20.5973
# firm obstacle               1.0000
# Name: 420, dtype: float64
# cruise speed               39.3790
# image resolution           67.1841
# illuminance                48.7692
# controls responsiveness    86.7376
# power                      31.0000
# smoke intensity            37.4754
# obstacle size               8.0487
# obstacle distance          20.5973
# firm obstacle               1.0000
# Name: 420, dtype: float64
# cruise speed               39.3790
# image resolution           67.1841
# illuminance                48.7692
# controls responsiveness    86.7376
# power                      31.0000
# smoke intensity            37.4754
# obstacle size               8.0487
# obstacle distance          20.5973
# firm obstacle               1.0000
# Name: 420, dtype: float64
# cruise speed               21.7037
# image resolution           32.1866
# illuminance                62.5943
# controls responsiveness    65.7713
# power                      94.0000
# smoke intensity            32.8778
# obstacle size              66.6337
# obstacle distance          51.1391
# firm obstacle               0.0000
# Name: 430, dtype: float64
# cruise speed               21.7037
# image resolution           32.1866
# illuminance                62.5943
# controls responsiveness    65.7713
# power                      94.0000
# smoke intensity            32.8778
# obstacle size              66.6337
# obstacle distance          51.1391
# firm obstacle               0.0000
# Name: 430, dtype: float64
# cruise speed               21.7037
# image resolution           32.1866
# illuminance                62.5943
# controls responsiveness    65.7713
# power                      94.0000
# smoke intensity            32.8778
# obstacle size              66.6337
# obstacle distance          51.1391
# firm obstacle               0.0000
# Name: 430, dtype: float64
# cruise speed               21.7037
# image resolution           32.1866
# illuminance                62.5943
# controls responsiveness    65.7713
# power                      94.0000
# smoke intensity            32.8778
# obstacle size              66.6337
# obstacle distance          51.1391
# firm obstacle               0.0000
# Name: 430, dtype: float64
# cruise speed                4.4998
# image resolution           42.8669
# illuminance                90.1444
# controls responsiveness    96.5711
# power                      16.0000
# smoke intensity            20.3634
# obstacle size              46.3978
# obstacle distance          90.8966
# firm obstacle               1.0000
# Name: 463, dtype: float64
# cruise speed                4.4998
# image resolution           42.8669
# illuminance                90.1444
# controls responsiveness    96.5711
# power                      16.0000
# smoke intensity            20.3634
# obstacle size              46.3978
# obstacle distance          90.8966
# firm obstacle               1.0000
# Name: 463, dtype: float64
# cruise speed                4.4998
# image resolution           42.8669
# illuminance                90.1444
# controls responsiveness    96.5711
# power                      16.0000
# smoke intensity            20.3634
# obstacle size              46.3978
# obstacle distance          90.8966
# firm obstacle               1.0000
# Name: 463, dtype: float64
# cruise speed                4.4998
# image resolution           42.8669
# illuminance                90.1444
# controls responsiveness    96.5711
# power                      16.0000
# smoke intensity            20.3634
# obstacle size              46.3978
# obstacle distance          90.8966
# firm obstacle               1.0000
# Name: 463, dtype: float64
# cruise speed               51.5513
# image resolution           21.0699
# illuminance                71.9446
# controls responsiveness    57.8169
# power                      41.0000
# smoke intensity             0.4590
# obstacle size              44.9928
# obstacle distance          60.8790
# firm obstacle               1.0000
# Name: 481, dtype: float64
# cruise speed               51.5513
# image resolution           21.0699
# illuminance                71.9446
# controls responsiveness    57.8169
# power                      41.0000
# smoke intensity             0.4590
# obstacle size              44.9928
# obstacle distance          60.8790
# firm obstacle               1.0000
# Name: 481, dtype: float64
# cruise speed               51.5513
# image resolution           21.0699
# illuminance                71.9446
# controls responsiveness    57.8169
# power                      41.0000
# smoke intensity             0.4590
# obstacle size              44.9928
# obstacle distance          60.8790
# firm obstacle               1.0000
# Name: 481, dtype: float64
# cruise speed               51.5513
# image resolution           21.0699
# illuminance                71.9446
# controls responsiveness    57.8169
# power                      41.0000
# smoke intensity             0.4590
# obstacle size              44.9928
# obstacle distance          60.8790
# firm obstacle               1.0000
# Name: 481, dtype: float64
# cruise speed               32.3512
# image resolution           51.0764
# illuminance                36.6766
# controls responsiveness    26.1529
# power                      71.0000
# smoke intensity            44.9175
# obstacle size              51.8722
# obstacle distance          56.0688
# firm obstacle               1.0000
# Name: 532, dtype: float64
# cruise speed               32.3512
# image resolution           51.0764
# illuminance                36.6766
# controls responsiveness    26.1529
# power                      71.0000
# smoke intensity            44.9175
# obstacle size              51.8722
# obstacle distance          56.0688
# firm obstacle               1.0000
# Name: 532, dtype: float64
# cruise speed               32.3512
# image resolution           51.0764
# illuminance                36.6766
# controls responsiveness    26.1529
# power                      71.0000
# smoke intensity            44.9175
# obstacle size              51.8722
# obstacle distance          56.0688
# firm obstacle               1.0000
# Name: 532, dtype: float64
# cruise speed               32.3512
# image resolution           51.0764
# illuminance                36.6766
# controls responsiveness    26.1529
# power                      71.0000
# smoke intensity            44.9175
# obstacle size              51.8722
# obstacle distance          56.0688
# firm obstacle               1.0000
# Name: 532, dtype: float64
# cruise speed               71.9996
# image resolution           99.8804
# illuminance                68.7445
# controls responsiveness    55.0820
# power                      17.0000
# smoke intensity            16.9844
# obstacle size              35.9386
# obstacle distance          42.2894
# firm obstacle               1.0000
# Name: 535, dtype: float64
# cruise speed               71.9996
# image resolution           99.8804
# illuminance                68.7445
# controls responsiveness    55.0820
# power                      17.0000
# smoke intensity            16.9844
# obstacle size              35.9386
# obstacle distance          42.2894
# firm obstacle               1.0000
# Name: 535, dtype: float64
# cruise speed               71.9996
# image resolution           99.8804
# illuminance                68.7445
# controls responsiveness    55.0820
# power                      17.0000
# smoke intensity            16.9844
# obstacle size              35.9386
# obstacle distance          42.2894
# firm obstacle               1.0000
# Name: 535, dtype: float64
# cruise speed               71.9996
# image resolution           99.8804
# illuminance                68.7445
# controls responsiveness    55.0820
# power                      17.0000
# smoke intensity            16.9844
# obstacle size              35.9386
# obstacle distance          42.2894
# firm obstacle               1.0000
# Name: 535, dtype: float64
# cruise speed               53.7990
# image resolution           41.5485
# illuminance                70.2415
# controls responsiveness    92.5972
# power                      96.0000
# smoke intensity             1.0299
# obstacle size              32.4793
# obstacle distance          41.6505
# firm obstacle               1.0000
# Name: 550, dtype: float64
# cruise speed               53.7990
# image resolution           41.5485
# illuminance                70.2415
# controls responsiveness    92.5972
# power                      96.0000
# smoke intensity             1.0299
# obstacle size              32.4793
# obstacle distance          41.6505
# firm obstacle               1.0000
# Name: 550, dtype: float64
# cruise speed               53.7990
# image resolution           41.5485
# illuminance                70.2415
# controls responsiveness    92.5972
# power                      96.0000
# smoke intensity             1.0299
# obstacle size              32.4793
# obstacle distance          41.6505
# firm obstacle               1.0000
# Name: 550, dtype: float64
# cruise speed               53.7990
# image resolution           41.5485
# illuminance                70.2415
# controls responsiveness    92.5972
# power                      96.0000
# smoke intensity             1.0299
# obstacle size              32.4793
# obstacle distance          41.6505
# firm obstacle               1.0000
# Name: 550, dtype: float64
# cruise speed               36.2452
# image resolution           21.9281
# illuminance                54.7876
# controls responsiveness    18.9289
# power                      96.0000
# smoke intensity            47.5044
# obstacle size              90.4812
# obstacle distance          46.9917
# firm obstacle               1.0000
# Name: 600, dtype: float64
# cruise speed               36.2452
# image resolution           21.9281
# illuminance                54.7876
# controls responsiveness    18.9289
# power                      96.0000
# smoke intensity            47.5044
# obstacle size              90.4812
# obstacle distance          46.9917
# firm obstacle               1.0000
# Name: 600, dtype: float64
# cruise speed               36.2452
# image resolution           21.9281
# illuminance                54.7876
# controls responsiveness    18.9289
# power                      96.0000
# smoke intensity            47.5044
# obstacle size              90.4812
# obstacle distance          46.9917
# firm obstacle               1.0000
# Name: 600, dtype: float64
# cruise speed               36.2452
# image resolution           21.9281
# illuminance                54.7876
# controls responsiveness    18.9289
# power                      96.0000
# smoke intensity            47.5044
# obstacle size              90.4812
# obstacle distance          46.9917
# firm obstacle               1.0000
# Name: 600, dtype: float64
# cruise speed               47.5972
# image resolution           43.1090
# illuminance                95.1382
# controls responsiveness    42.9037
# power                      12.0000
# smoke intensity            30.0720
# obstacle size              82.5993
# obstacle distance          54.7431
# firm obstacle               1.0000
# Name: 634, dtype: float64
# cruise speed               47.5972
# image resolution           43.1090
# illuminance                95.1382
# controls responsiveness    42.9037
# power                      12.0000
# smoke intensity            30.0720
# obstacle size              82.5993
# obstacle distance          54.7431
# firm obstacle               1.0000
# Name: 634, dtype: float64
# cruise speed               47.5972
# image resolution           43.1090
# illuminance                95.1382
# controls responsiveness    42.9037
# power                      12.0000
# smoke intensity            30.0720
# obstacle size              82.5993
# obstacle distance          54.7431
# firm obstacle               1.0000
# Name: 634, dtype: float64
# cruise speed               47.5972
# image resolution           43.1090
# illuminance                95.1382
# controls responsiveness    42.9037
# power                      12.0000
# smoke intensity            30.0720
# obstacle size              82.5993
# obstacle distance          54.7431
# firm obstacle               1.0000
# Name: 634, dtype: float64
# cruise speed                8.5292
# image resolution           89.1708
# illuminance                50.0895
# controls responsiveness    80.5253
# power                      64.0000
# smoke intensity            81.2050
# obstacle size              36.1167
# obstacle distance          40.1561
# firm obstacle               0.0000
# Name: 718, dtype: float64
# cruise speed                8.5292
# image resolution           89.1708
# illuminance                50.0895
# controls responsiveness    80.5253
# power                      64.0000
# smoke intensity            81.2050
# obstacle size              36.1167
# obstacle distance          40.1561
# firm obstacle               0.0000
# Name: 718, dtype: float64
# cruise speed                8.5292
# image resolution           89.1708
# illuminance                50.0895
# controls responsiveness    80.5253
# power                      64.0000
# smoke intensity            81.2050
# obstacle size              36.1167
# obstacle distance          40.1561
# firm obstacle               0.0000
# Name: 718, dtype: float64
# cruise speed                8.5292
# image resolution           89.1708
# illuminance                50.0895
# controls responsiveness    80.5253
# power                      64.0000
# smoke intensity            81.2050
# obstacle size              36.1167
# obstacle distance          40.1561
# firm obstacle               0.0000
# Name: 718, dtype: float64
# cruise speed               20.0201
# image resolution           82.9284
# illuminance                79.6514
# controls responsiveness    90.5009
# power                      54.0000
# smoke intensity            20.2179
# obstacle size              27.0097
# obstacle distance          26.9309
# firm obstacle               1.0000
# Name: 769, dtype: float64
# cruise speed               20.0201
# image resolution           82.9284
# illuminance                79.6514
# controls responsiveness    90.5009
# power                      54.0000
# smoke intensity            20.2179
# obstacle size              27.0097
# obstacle distance          26.9309
# firm obstacle               1.0000
# Name: 769, dtype: float64
# cruise speed               20.0201
# image resolution           82.9284
# illuminance                79.6514
# controls responsiveness    90.5009
# power                      54.0000
# smoke intensity            20.2179
# obstacle size              27.0097
# obstacle distance          26.9309
# firm obstacle               1.0000
# Name: 769, dtype: float64
# cruise speed               20.0201
# image resolution           82.9284
# illuminance                79.6514
# controls responsiveness    90.5009
# power                      54.0000
# smoke intensity            20.2179
# obstacle size              27.0097
# obstacle distance          26.9309
# firm obstacle               1.0000
# Name: 769, dtype: float64
# cruise speed               40.2963
# image resolution           33.8804
# illuminance                45.4978
# controls responsiveness    57.8424
# power                      58.0000
# smoke intensity            56.8026
# obstacle size              89.5342
# obstacle distance          20.5908
# firm obstacle               1.0000
# Name: 779, dtype: float64
# cruise speed               40.2963
# image resolution           33.8804
# illuminance                45.4978
# controls responsiveness    57.8424
# power                      58.0000
# smoke intensity            56.8026
# obstacle size              89.5342
# obstacle distance          20.5908
# firm obstacle               1.0000
# Name: 779, dtype: float64
# cruise speed               40.2963
# image resolution           33.8804
# illuminance                45.4978
# controls responsiveness    57.8424
# power                      58.0000
# smoke intensity            56.8026
# obstacle size              89.5342
# obstacle distance          20.5908
# firm obstacle               1.0000
# Name: 779, dtype: float64
# cruise speed               40.2963
# image resolution           33.8804
# illuminance                45.4978
# controls responsiveness    57.8424
# power                      58.0000
# smoke intensity            56.8026
# obstacle size              89.5342
# obstacle distance          20.5908
# firm obstacle               1.0000
# Name: 779, dtype: float64
# cruise speed               51.0078
# image resolution           43.2019
# illuminance                64.9206
# controls responsiveness    62.0125
# power                      54.0000
# smoke intensity             1.3646
# obstacle size              40.9205
# obstacle distance          77.0119
# firm obstacle               1.0000
# Name: 780, dtype: float64
# cruise speed               51.0078
# image resolution           43.2019
# illuminance                64.9206
# controls responsiveness    62.0125
# power                      54.0000
# smoke intensity             1.3646
# obstacle size              40.9205
# obstacle distance          77.0119
# firm obstacle               1.0000
# Name: 780, dtype: float64
# cruise speed               51.0078
# image resolution           43.2019
# illuminance                64.9206
# controls responsiveness    62.0125
# power                      54.0000
# smoke intensity             1.3646
# obstacle size              40.9205
# obstacle distance          77.0119
# firm obstacle               1.0000
# Name: 780, dtype: float64
# cruise speed               51.0078
# image resolution           43.2019
# illuminance                64.9206
# controls responsiveness    62.0125
# power                      54.0000
# smoke intensity             1.3646
# obstacle size              40.9205
# obstacle distance          77.0119
# firm obstacle               1.0000
# Name: 780, dtype: float64
# cruise speed               50.0495
# image resolution           91.1528
# illuminance                81.3698
# controls responsiveness    76.9036
# power                      18.0000
# smoke intensity            48.5361
# obstacle size              45.6421
# obstacle distance          86.0540
# firm obstacle               1.0000
# Name: 823, dtype: float64
# cruise speed               50.0495
# image resolution           91.1528
# illuminance                81.3698
# controls responsiveness    76.9036
# power                      18.0000
# smoke intensity            48.5361
# obstacle size              45.6421
# obstacle distance          86.0540
# firm obstacle               1.0000
# Name: 823, dtype: float64
# cruise speed               50.0495
# image resolution           91.1528
# illuminance                81.3698
# controls responsiveness    76.9036
# power                      18.0000
# smoke intensity            48.5361
# obstacle size              45.6421
# obstacle distance          86.0540
# firm obstacle               1.0000
# Name: 823, dtype: float64
# cruise speed               50.0495
# image resolution           91.1528
# illuminance                81.3698
# controls responsiveness    76.9036
# power                      18.0000
# smoke intensity            48.5361
# obstacle size              45.6421
# obstacle distance          86.0540
# firm obstacle               1.0000
# Name: 823, dtype: float64
# cruise speed               45.2684
# image resolution           94.3731
# illuminance                81.8874
# controls responsiveness    86.7941
# power                      30.0000
# smoke intensity            23.6341
# obstacle size              30.2148
# obstacle distance          40.6917
# firm obstacle               0.0000
# Name: 833, dtype: float64
# cruise speed               45.2684
# image resolution           94.3731
# illuminance                81.8874
# controls responsiveness    86.7941
# power                      30.0000
# smoke intensity            23.6341
# obstacle size              30.2148
# obstacle distance          40.6917
# firm obstacle               0.0000
# Name: 833, dtype: float64
# cruise speed               45.2684
# image resolution           94.3731
# illuminance                81.8874
# controls responsiveness    86.7941
# power                      30.0000
# smoke intensity            23.6341
# obstacle size              30.2148
# obstacle distance          40.6917
# firm obstacle               0.0000
# Name: 833, dtype: float64
# cruise speed               45.2684
# image resolution           94.3731
# illuminance                81.8874
# controls responsiveness    86.7941
# power                      30.0000
# smoke intensity            23.6341
# obstacle size              30.2148
# obstacle distance          40.6917
# firm obstacle               0.0000
# Name: 833, dtype: float64
# cruise speed               24.3097
# image resolution           92.4634
# illuminance                94.1820
# controls responsiveness    67.5477
# power                      37.0000
# smoke intensity            62.8540
# obstacle size              18.3089
# obstacle distance          88.8471
# firm obstacle               0.0000
# Name: 847, dtype: float64
# cruise speed               24.3097
# image resolution           92.4634
# illuminance                94.1820
# controls responsiveness    67.5477
# power                      37.0000
# smoke intensity            62.8540
# obstacle size              18.3089
# obstacle distance          88.8471
# firm obstacle               0.0000
# Name: 847, dtype: float64
# cruise speed               24.3097
# image resolution           92.4634
# illuminance                94.1820
# controls responsiveness    67.5477
# power                      37.0000
# smoke intensity            62.8540
# obstacle size              18.3089
# obstacle distance          88.8471
# firm obstacle               0.0000
# Name: 847, dtype: float64
# cruise speed               24.3097
# image resolution           92.4634
# illuminance                94.1820
# controls responsiveness    67.5477
# power                      37.0000
# smoke intensity            62.8540
# obstacle size              18.3089
# obstacle distance          88.8471
# firm obstacle               0.0000
# Name: 847, dtype: float64
# cruise speed               14.4731
# image resolution           90.6909
# illuminance                97.5764
# controls responsiveness    95.1235
# power                      32.0000
# smoke intensity            36.9203
# obstacle size              55.5914
# obstacle distance          58.5227
# firm obstacle               0.0000
# Name: 870, dtype: float64
# cruise speed               14.4731
# image resolution           90.6909
# illuminance                97.5764
# controls responsiveness    95.1235
# power                      32.0000
# smoke intensity            36.9203
# obstacle size              55.5914
# obstacle distance          58.5227
# firm obstacle               0.0000
# Name: 870, dtype: float64
# cruise speed               14.4731
# image resolution           90.6909
# illuminance                97.5764
# controls responsiveness    95.1235
# power                      32.0000
# smoke intensity            36.9203
# obstacle size              55.5914
# obstacle distance          58.5227
# firm obstacle               0.0000
# Name: 870, dtype: float64
# cruise speed               14.4731
# image resolution           90.6909
# illuminance                97.5764
# controls responsiveness    95.1235
# power                      32.0000
# smoke intensity            36.9203
# obstacle size              55.5914
# obstacle distance          58.5227
# firm obstacle               0.0000
# Name: 870, dtype: float64
# cruise speed               45.5780
# image resolution           60.5750
# illuminance                84.4333
# controls responsiveness    62.3245
# power                      19.0000
# smoke intensity            72.4659
# obstacle size              76.5424
# obstacle distance          39.9429
# firm obstacle               1.0000
# Name: 890, dtype: float64
# cruise speed               45.5780
# image resolution           60.5750
# illuminance                84.4333
# controls responsiveness    62.3245
# power                      19.0000
# smoke intensity            72.4659
# obstacle size              76.5424
# obstacle distance          39.9429
# firm obstacle               1.0000
# Name: 890, dtype: float64
# cruise speed               45.5780
# image resolution           60.5750
# illuminance                84.4333
# controls responsiveness    62.3245
# power                      19.0000
# smoke intensity            72.4659
# obstacle size              76.5424
# obstacle distance          39.9429
# firm obstacle               1.0000
# Name: 890, dtype: float64
# cruise speed               45.5780
# image resolution           60.5750
# illuminance                84.4333
# controls responsiveness    62.3245
# power                      19.0000
# smoke intensity            72.4659
# obstacle size              76.5424
# obstacle distance          39.9429
# firm obstacle               1.0000
# Name: 890, dtype: float64
# cruise speed               10.1458
# image resolution           89.6897
# illuminance                97.3592
# controls responsiveness    54.1410
# power                      35.0000
# smoke intensity            40.4405
# obstacle size              29.8348
# obstacle distance          75.7033
# firm obstacle               1.0000
# Name: 916, dtype: float64
# cruise speed               10.1458
# image resolution           89.6897
# illuminance                97.3592
# controls responsiveness    54.1410
# power                      35.0000
# smoke intensity            40.4405
# obstacle size              29.8348
# obstacle distance          75.7033
# firm obstacle               1.0000
# Name: 916, dtype: float64
# cruise speed               10.1458
# image resolution           89.6897
# illuminance                97.3592
# controls responsiveness    54.1410
# power                      35.0000
# smoke intensity            40.4405
# obstacle size              29.8348
# obstacle distance          75.7033
# firm obstacle               1.0000
# Name: 916, dtype: float64
# cruise speed               10.1458
# image resolution           89.6897
# illuminance                97.3592
# controls responsiveness    54.1410
# power                      35.0000
# smoke intensity            40.4405
# obstacle size              29.8348
# obstacle distance          75.7033
# firm obstacle               1.0000
# Name: 916, dtype: float64
# cruise speed               44.8553
# image resolution           86.1779
# illuminance                64.0325
# controls responsiveness    61.0353
# power                      92.0000
# smoke intensity            48.9546
# obstacle size              42.2621
# obstacle distance          63.8554
# firm obstacle               1.0000
# Name: 983, dtype: float64
# cruise speed               44.8553
# image resolution           86.1779
# illuminance                64.0325
# controls responsiveness    61.0353
# power                      92.0000
# smoke intensity            48.9546
# obstacle size              42.2621
# obstacle distance          63.8554
# firm obstacle               1.0000
# Name: 983, dtype: float64
# cruise speed               44.8553
# image resolution           86.1779
# illuminance                64.0325
# controls responsiveness    61.0353
# power                      92.0000
# smoke intensity            48.9546
# obstacle size              42.2621
# obstacle distance          63.8554
# firm obstacle               1.0000
# Name: 983, dtype: float64
# cruise speed               44.8553
# image resolution           86.1779
# illuminance                64.0325
# controls responsiveness    61.0353
# power                      92.0000
# smoke intensity            48.9546
# obstacle size              42.2621
# obstacle distance          63.8554
# firm obstacle               1.0000
# Name: 983, dtype: float64
# cruise speed               20.6496
# image resolution           48.4411
# illuminance                75.8719
# controls responsiveness    53.8548
# power                      41.0000
# smoke intensity            87.6355
# obstacle size              43.4319
# obstacle distance          42.7091
# firm obstacle               1.0000
# Name: 994, dtype: float64
# cruise speed               20.6496
# image resolution           48.4411
# illuminance                75.8719
# controls responsiveness    53.8548
# power                      41.0000
# smoke intensity            87.6355
# obstacle size              43.4319
# obstacle distance          42.7091
# firm obstacle               1.0000
# Name: 994, dtype: float64
# cruise speed               20.6496
# image resolution           48.4411
# illuminance                75.8719
# controls responsiveness    53.8548
# power                      41.0000
# smoke intensity            87.6355
# obstacle size              43.4319
# ...
# power                      37.0000
# smoke intensity            46.3124
# obstacle size              41.1268
# obstacle distance          54.3400
# firm obstacle               1.0000
# Name: 4742, dtype: float64
# cruise speed                4.4136
# image resolution           98.6967
# illuminance                20.4011
# controls responsiveness    98.6496
# power                      37.0000
# smoke intensity            46.3124
# obstacle size              41.1268
# obstacle distance          54.3400
# firm obstacle               1.0000
# Name: 4742, dtype: float64
# cruise speed                4.4136
# image resolution           98.6967
# illuminance                20.4011
# controls responsiveness    98.6496
# power                      37.0000
# smoke intensity            46.3124
# obstacle size              41.1268
# obstacle distance          54.3400
# firm obstacle               1.0000
# Name: 4742, dtype: float64
# cruise speed               30.4994
# image resolution           74.3351
# illuminance                71.9779
# controls responsiveness    87.7783
# power                      44.0000
# smoke intensity            86.8261
# obstacle size              30.1413
# obstacle distance          13.2004
# firm obstacle               1.0000
# Name: 4786, dtype: float64
# cruise speed               30.4994
# image resolution           74.3351
# illuminance                71.9779
# controls responsiveness    87.7783
# power                      44.0000
# smoke intensity            86.8261
# obstacle size              30.1413
# obstacle distance          13.2004
# firm obstacle               1.0000
# Name: 4786, dtype: float64
# cruise speed               30.4994
# image resolution           74.3351
# illuminance                71.9779
# controls responsiveness    87.7783
# power                      44.0000
# smoke intensity            86.8261
# obstacle size              30.1413
# obstacle distance          13.2004
# firm obstacle               1.0000
# Name: 4786, dtype: float64
# cruise speed               30.4994
# image resolution           74.3351
# illuminance                71.9779
# controls responsiveness    87.7783
# power                      44.0000
# smoke intensity            86.8261
# obstacle size              30.1413
# obstacle distance          13.2004
# firm obstacle               1.0000
# Name: 4786, dtype: float64
# cruise speed               36.7649
# image resolution           30.8458
# illuminance                81.5023
# controls responsiveness    80.7930
# power                      92.0000
# smoke intensity             7.5712
# obstacle size              19.2984
# obstacle distance          83.9684
# firm obstacle               1.0000
# Name: 4795, dtype: float64
# cruise speed               36.7649
# image resolution           30.8458
# illuminance                81.5023
# controls responsiveness    80.7930
# power                      92.0000
# smoke intensity             7.5712
# obstacle size              19.2984
# obstacle distance          83.9684
# firm obstacle               1.0000
# Name: 4795, dtype: float64
# cruise speed               36.7649
# image resolution           30.8458
# illuminance                81.5023
# controls responsiveness    80.7930
# power                      92.0000
# smoke intensity             7.5712
# obstacle size              19.2984
# obstacle distance          83.9684
# firm obstacle               1.0000
# Name: 4795, dtype: float64
# cruise speed               36.7649
# image resolution           30.8458
# illuminance                81.5023
# controls responsiveness    80.7930
# power                      92.0000
# smoke intensity             7.5712
# obstacle size              19.2984
# obstacle distance          83.9684
# firm obstacle               1.0000
# Name: 4795, dtype: float64
# cruise speed               54.2334
# image resolution           20.7933
# illuminance                99.5405
# controls responsiveness    27.4732
# power                      97.0000
# smoke intensity            62.3018
# obstacle size              81.3949
# obstacle distance          86.0821
# firm obstacle               1.0000
# Name: 4807, dtype: float64
# cruise speed               54.2334
# image resolution           20.7933
# illuminance                99.5405
# controls responsiveness    27.4732
# power                      97.0000
# smoke intensity            62.3018
# obstacle size              81.3949
# obstacle distance          86.0821
# firm obstacle               1.0000
# Name: 4807, dtype: float64
# cruise speed               54.2334
# image resolution           20.7933
# illuminance                99.5405
# controls responsiveness    27.4732
# power                      97.0000
# smoke intensity            62.3018
# obstacle size              81.3949
# obstacle distance          86.0821
# firm obstacle               1.0000
# Name: 4807, dtype: float64
# cruise speed               54.2334
# image resolution           20.7933
# illuminance                99.5405
# controls responsiveness    27.4732
# power                      97.0000
# smoke intensity            62.3018
# obstacle size              81.3949
# obstacle distance          86.0821
# firm obstacle               1.0000
# Name: 4807, dtype: float64
# cruise speed               15.9403
# image resolution           97.1871
# illuminance                89.3429
# controls responsiveness    78.7299
# power                      34.0000
# smoke intensity            60.8554
# obstacle size              79.9970
# obstacle distance          81.8318
# firm obstacle               0.0000
# Name: 4856, dtype: float64
# cruise speed               15.9403
# image resolution           97.1871
# illuminance                89.3429
# controls responsiveness    78.7299
# power                      34.0000
# smoke intensity            60.8554
# obstacle size              79.9970
# obstacle distance          81.8318
# firm obstacle               0.0000
# Name: 4856, dtype: float64
# cruise speed               15.9403
# image resolution           97.1871
# illuminance                89.3429
# controls responsiveness    78.7299
# power                      34.0000
# smoke intensity            60.8554
# obstacle size              79.9970
# obstacle distance          81.8318
# firm obstacle               0.0000
# Name: 4856, dtype: float64
# cruise speed               15.9403
# image resolution           97.1871
# illuminance                89.3429
# controls responsiveness    78.7299
# power                      34.0000
# smoke intensity            60.8554
# obstacle size              79.9970
# obstacle distance          81.8318
# firm obstacle               0.0000
# Name: 4856, dtype: float64
# cruise speed               33.2786
# image resolution           84.7165
# illuminance                49.8893
# controls responsiveness    43.4576
# power                      96.0000
# smoke intensity            68.0800
# obstacle size              43.5352
# obstacle distance          62.6665
# firm obstacle               1.0000
# Name: 4873, dtype: float64
# cruise speed               33.2786
# image resolution           84.7165
# illuminance                49.8893
# controls responsiveness    43.4576
# power                      96.0000
# smoke intensity            68.0800
# obstacle size              43.5352
# obstacle distance          62.6665
# firm obstacle               1.0000
# Name: 4873, dtype: float64
# cruise speed               33.2786
# image resolution           84.7165
# illuminance                49.8893
# controls responsiveness    43.4576
# power                      96.0000
# smoke intensity            68.0800
# obstacle size              43.5352
# obstacle distance          62.6665
# firm obstacle               1.0000
# Name: 4873, dtype: float64
# cruise speed               33.2786
# image resolution           84.7165
# illuminance                49.8893
# controls responsiveness    43.4576
# power                      96.0000
# smoke intensity            68.0800
# obstacle size              43.5352
# obstacle distance          62.6665
# firm obstacle               1.0000
# Name: 4873, dtype: float64
# cruise speed               34.9404
# image resolution           46.6588
# illuminance                67.9912
# controls responsiveness    33.0430
# power                      73.0000
# smoke intensity             2.2796
# obstacle size              89.1663
# obstacle distance          63.9227
# firm obstacle               1.0000
# Name: 4899, dtype: float64
# cruise speed               34.9404
# image resolution           46.6588
# illuminance                67.9912
# controls responsiveness    33.0430
# power                      73.0000
# smoke intensity             2.2796
# obstacle size              89.1663
# obstacle distance          63.9227
# firm obstacle               1.0000
# Name: 4899, dtype: float64
# cruise speed               34.9404
# image resolution           46.6588
# illuminance                67.9912
# controls responsiveness    33.0430
# power                      73.0000
# smoke intensity             2.2796
# obstacle size              89.1663
# obstacle distance          63.9227
# firm obstacle               1.0000
# Name: 4899, dtype: float64
# cruise speed               34.9404
# image resolution           46.6588
# illuminance                67.9912
# controls responsiveness    33.0430
# power                      73.0000
# smoke intensity             2.2796
# obstacle size              89.1663
# obstacle distance          63.9227
# firm obstacle               1.0000
# Name: 4899, dtype: float64
# cruise speed                2.5293
# image resolution           34.9705
# illuminance                46.8863
# controls responsiveness    63.9680
# power                      82.0000
# smoke intensity            39.4008
# obstacle size              82.3320
# obstacle distance          77.4036
# firm obstacle               1.0000
# Name: 4903, dtype: float64
# cruise speed                2.5293
# image resolution           34.9705
# illuminance                46.8863
# controls responsiveness    63.9680
# power                      82.0000
# smoke intensity            39.4008
# obstacle size              82.3320
# obstacle distance          77.4036
# firm obstacle               1.0000
# Name: 4903, dtype: float64
# cruise speed                2.5293
# image resolution           34.9705
# illuminance                46.8863
# controls responsiveness    63.9680
# power                      82.0000
# smoke intensity            39.4008
# obstacle size              82.3320
# obstacle distance          77.4036
# firm obstacle               1.0000
# Name: 4903, dtype: float64
# cruise speed                2.5293
# image resolution           34.9705
# illuminance                46.8863
# controls responsiveness    63.9680
# power                      82.0000
# smoke intensity            39.4008
# obstacle size              82.3320
# obstacle distance          77.4036
# firm obstacle               1.0000
# Name: 4903, dtype: float64
# cruise speed               64.8375
# image resolution           85.3328
# illuminance                88.8286
# controls responsiveness    47.0238
# power                      37.0000
# smoke intensity            54.3896
# obstacle size              71.8407
# obstacle distance          72.9755
# firm obstacle               1.0000
# Name: 4949, dtype: float64
# cruise speed               64.8375
# image resolution           85.3328
# illuminance                88.8286
# controls responsiveness    47.0238
# power                      37.0000
# smoke intensity            54.3896
# obstacle size              71.8407
# obstacle distance          72.9755
# firm obstacle               1.0000
# Name: 4949, dtype: float64
# cruise speed               64.8375
# image resolution           85.3328
# illuminance                88.8286
# controls responsiveness    47.0238
# power                      37.0000
# smoke intensity            54.3896
# obstacle size              71.8407
# obstacle distance          72.9755
# firm obstacle               1.0000
# Name: 4949, dtype: float64
# cruise speed               64.8375
# image resolution           85.3328
# illuminance                88.8286
# controls responsiveness    47.0238
# power                      37.0000
# smoke intensity            54.3896
# obstacle size              71.8407
# obstacle distance          72.9755
# firm obstacle               1.0000
# Name: 4949, dtype: float64
# cruise speed               52.3667
# image resolution           86.2403
# illuminance                65.0234
# controls responsiveness    89.0712
# power                      82.0000
# smoke intensity            25.4637
# obstacle size               6.8354
# obstacle distance          22.7518
# firm obstacle               1.0000
# Name: 4963, dtype: float64
# cruise speed               52.3667
# image resolution           86.2403
# illuminance                65.0234
# controls responsiveness    89.0712
# power                      82.0000
# smoke intensity            25.4637
# obstacle size               6.8354
# obstacle distance          22.7518
# firm obstacle               1.0000
# Name: 4963, dtype: float64
# cruise speed               52.3667
# image resolution           86.2403
# illuminance                65.0234
# controls responsiveness    89.0712
# power                      82.0000
# smoke intensity            25.4637
# obstacle size               6.8354
# obstacle distance          22.7518
# firm obstacle               1.0000
# Name: 4963, dtype: float64
# cruise speed               52.3667
# image resolution           86.2403
# illuminance                65.0234
# controls responsiveness    89.0712
# power                      82.0000
# smoke intensity            25.4637
# obstacle size               6.8354
# obstacle distance          22.7518
# firm obstacle               1.0000
# Name: 4963, dtype: float64
# cruise speed               34.3001
# image resolution           67.8008
# illuminance                35.7216
# controls responsiveness    67.0588
# power                      82.0000
# smoke intensity            56.6829
# obstacle size              74.4598
# obstacle distance          54.0523
# firm obstacle               1.0000
# Name: 4973, dtype: float64
# cruise speed               34.3001
# image resolution           67.8008
# illuminance                35.7216
# controls responsiveness    67.0588
# power                      82.0000
# smoke intensity            56.6829
# obstacle size              74.4598
# obstacle distance          54.0523
# firm obstacle               1.0000
# Name: 4973, dtype: float64
# cruise speed               34.3001
# image resolution           67.8008
# illuminance                35.7216
# controls responsiveness    67.0588
# power                      82.0000
# smoke intensity            56.6829
# obstacle size              74.4598
# obstacle distance          54.0523
# firm obstacle               1.0000
# Name: 4973, dtype: float64
# cruise speed               34.3001
# image resolution           67.8008
# illuminance                35.7216
# controls responsiveness    67.0588
# power                      82.0000
# smoke intensity            56.6829
# obstacle size              74.4598
# obstacle distance          54.0523
# firm obstacle               1.0000
# Name: 4973, dtype: float64
# cruise speed                68.4368
# image resolution            48.5526
# illuminance                 59.2753
# controls responsiveness     64.8479
# power                      100.0000
# smoke intensity             55.9474
# obstacle size               78.7790
# obstacle distance           24.6323
# firm obstacle                1.0000
# Name: 4997, dtype: float64
# cruise speed                68.4368
# image resolution            48.5526
# illuminance                 59.2753
# controls responsiveness     64.8479
# power                      100.0000
# smoke intensity             55.9474
# obstacle size               78.7790
# obstacle distance           24.6323
# firm obstacle                1.0000
# Name: 4997, dtype: float64
# cruise speed                68.4368
# image resolution            48.5526
# illuminance                 59.2753
# controls responsiveness     64.8479
# power                      100.0000
# smoke intensity             55.9474
# obstacle size               78.7790
# obstacle distance           24.6323
# firm obstacle                1.0000
# Name: 4997, dtype: float64
# cruise speed                68.4368
# image resolution            48.5526
# illuminance                 59.2753
# controls responsiveness     64.8479
# power                      100.0000
# smoke intensity             55.9474
# obstacle size               78.7790
# obstacle distance           24.6323
# firm obstacle                1.0000
# Name: 4997, dtype: float64

# %%
targets = np.zeros((all_true_training_dataset.shape[0], len(models)))
for i in range(all_true_training_dataset.shape[0]):
    for j in range(len(models)):
        targets[i,j] = models[j].predict(all_true_training_dataset.iloc[i].values.reshape(1, -1))

all_yes_t = np.all(targets==1, axis = 1)

# %%
np.count_nonzero(all_yes_t == 1), targets.shape, len(sat)
# Out:
# (19, (205, 4), 6)

# %% [markdown]
# Validate the function on a test set (500 samples)

# %%
n_samples_val = validation_df.shape[0]

# %%
len(exp_intersected)
# Out:
# 4

# %%
y_pred = np.zeros((n_samples_val, len(models)))
y_real = np.zeros((n_samples_val, len(models)))
y_anch = np.zeros((n_samples_val, len(models)))


for i in range(n_samples_val):

    y_real[i] = validation_df.iloc[i].values[9:]

    values = validation_df.iloc[i].values[:9]
    for j in range(len(models)):
        y_pred[i,j] = models[j].predict(values.reshape(1, -1))
        y_anch[i,j] = 0
        flag = True
        for k in feature_names:
            if k in exp_intersected[j]:
                if not inside(validation_df.iloc[i][k], exp_intersected[j][k]):
                    flag = False
                    break
        if flag:
            y_anch[i,j] = 1

# %%
y_real_all = np.all(targets==1, axis = 1)
y_pred_all = np.all(y_pred==1, axis = 1)
y_anch_all = np.all(y_anch==1, axis = 1)

# %%
y_real_all[y_real_all == True], y_pred_all[y_pred_all == True], y_anch_all[y_anch_all == True].shape
# Out:
# (array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True]),
#  array([ True]),
#  (0,))

# %%
r_p = np.zeros(n_samples_val)
r_a = np.zeros(n_samples_val)
p_a = np.zeros(n_samples_val)

for i, req in enumerate(req_names):
    for j in range(n_samples_val):
        r_p[j] = y_pred[j,i] and y_real[j,i]
        r_a[j] = y_anch[j,i] and y_real[j,i]
        p_a[j] = y_anch[j,i] and y_pred[j,i]

r_p = np.sum(r_p)
r_a = np.sum(r_a)
p_a = np.sum(p_a)
r_p, r_a, p_a, [np.count_nonzero(y_real[:,i]) for i in range(4)]
# Out:
# (93.0, 0.0, 0.0, [178, 54, 88, 121])
