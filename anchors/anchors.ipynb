# %% [markdown]
# # Anchors

# %%
pip install anchor-exp
# Out:
# Requirement already satisfied: anchor-exp in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (0.0.2.0)
# Requirement already satisfied: numpy in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from anchor-exp) (1.24.1)
# Requirement already satisfied: scipy in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from anchor-exp) (1.10.0)
# Requirement already satisfied: spacy in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from anchor-exp) (3.8.5)
# Requirement already satisfied: lime in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from anchor-exp) (0.2.0.1)
# Requirement already satisfied: scikit-learn>=0.22 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from anchor-exp) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from scikit-learn>=0.22->anchor-exp) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from scikit-learn>=0.22->anchor-exp) (3.6.0)
# Requirement already satisfied: matplotlib in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from lime->anchor-exp) (3.6.3)
# Requirement already satisfied: tqdm in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from lime->anchor-exp) (4.67.1)
# Requirement already satisfied: scikit-image>=0.12 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from lime->anchor-exp) (0.24.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from spacy->anchor-exp) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from spacy->anchor-exp) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from spacy->anchor-exp) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from spacy->anchor-exp) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from spacy->anchor-exp) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from spacy->anchor-exp) (8.3.4)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from spacy->anchor-exp) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from spacy->anchor-exp) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from spacy->anchor-exp) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from spacy->anchor-exp) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from spacy->anchor-exp) (0.15.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from spacy->anchor-exp) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from spacy->anchor-exp) (2.11.3)
# Requirement already satisfied: jinja2 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from spacy->anchor-exp) (3.1.6)
# Requirement already satisfied: setuptools in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from spacy->anchor-exp) (65.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from spacy->anchor-exp) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from spacy->anchor-exp) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy->anchor-exp) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->anchor-exp) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->anchor-exp) (2.33.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->anchor-exp) (4.13.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy->anchor-exp) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy->anchor-exp) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy->anchor-exp) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy->anchor-exp) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy->anchor-exp) (2025.1.31)
# Requirement already satisfied: networkx>=2.8 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from scikit-image>=0.12->lime->anchor-exp) (3.4.2)
# Requirement already satisfied: pillow>=9.1 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from scikit-image>=0.12->lime->anchor-exp) (11.1.0)
# Requirement already satisfied: imageio>=2.33 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from scikit-image>=0.12->lime->anchor-exp) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from scikit-image>=0.12->lime->anchor-exp) (2025.3.13)
# Requirement already satisfied: lazy-loader>=0.4 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from scikit-image>=0.12->lime->anchor-exp) (0.4)
# Requirement already satisfied: blis<1.3.0,>=1.2.0 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.4->spacy->anchor-exp) (1.2.1)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.4->spacy->anchor-exp) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy->anchor-exp) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy->anchor-exp) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy->anchor-exp) (14.0.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy->anchor-exp) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy->anchor-exp) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from jinja2->spacy->anchor-exp) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from matplotlib->lime->anchor-exp) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from matplotlib->lime->anchor-exp) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from matplotlib->lime->anchor-exp) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from matplotlib->lime->anchor-exp) (1.4.8)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from matplotlib->lime->anchor-exp) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from matplotlib->lime->anchor-exp) (2.9.0.post0)
# Requirement already satisfied: marisa-trie>=1.1.0 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy->anchor-exp) (1.2.1)
# Requirement already satisfied: six>=1.5 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->lime->anchor-exp) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy->anchor-exp) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy->anchor-exp) (2.19.1)
# Requirement already satisfied: wrapt in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy->anchor-exp) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /home/missy/Scrivania/XDA1.4/venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy->anchor-exp) (0.1.2)
#
# [notice] A new release of pip available: 22.3 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from __future__ import print_function
import numpy as np
np.random.seed(1)
import sys
import sklearn
import sklearn.ensemble
# %load_ext autoreload
# %autoreload 2
from anchor import utils
from anchor import anchor_tabular
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset_folder = '../datasets/dataset500.csv'
df = pd.read_csv(dataset_folder)

all_true_dataset = df[(df['req_0'] == 1) & (df['req_1'] == 1) & (df['req_2'] == 1) & (df['req_3'] == 1)]
all_true_dataset = all_true_dataset.drop(columns=['req_0','req_1', 'req_2', 'req_3'])
print(all_true_dataset.shape)
# Out:
# (12, 9)

# %%
path = '../datasets/dataset500'
df0 = df.drop(columns=['req_1', 'req_2', 'req_3'])
df0.to_csv(path + 'req0.csv', index=False)

df1 = df.drop(columns=['req_0', 'req_2', 'req_3'])
df1.to_csv(path + 'req1.csv', index=False)

df2 = df.drop(columns=['req_0', 'req_1', 'req_3'])
df2.to_csv(path + 'req2.csv', index=False)

df3 = df.drop(columns=['req_0', 'req_1', 'req_2'])
df3.to_csv(path + 'req3.csv', index=False)

# %%
datasets = []
dataframes = []
c= []
for i in range(4):
    dataset_folder = '../datasets/dataset500req' + str(i) + '.csv'
    datasets.append(utils.load_csv_dataset(dataset_folder, 9))

    c.append(sklearn.ensemble.GradientBoostingClassifier(random_state=1234))
    c[i].fit(datasets[i].train, datasets[i].labels_train)
    print('Train', sklearn.metrics.accuracy_score(datasets[i].labels_train, c[i].predict(datasets[i].train)))
    print('Test', sklearn.metrics.accuracy_score(datasets[i].labels_test, c[i].predict(datasets[i].test)))

    explainer = anchor_tabular.AnchorTabularExplainer(
        datasets[i].class_names, #it maps the 0 and 1 in the dataset's requirements to the class names
        datasets[i].feature_names,
        datasets[i].train,
        datasets[i].categorical_names)
    
    names = []
    for j in range(all_true_dataset.shape[0]):
        
        #do a csv with a prediction for each sample
        #print(all_true_dataset.iloc[i].values.reshape(1, -1)[0])
        with open('../datasets/anchorsReq' +str(i) +'.csv', 'a') as f:
            f.write('Prediction: %s\n' % (explainer.class_names[c[i].predict(all_true_dataset.iloc[j].values.reshape(1, -1))[0]]))
            exp = explainer.explain_instance(all_true_dataset.iloc[j].values.reshape(1, -1), c[i].predict, threshold=0.95)
            f.write('Anchor: %s\n' % (' AND '.join(exp.names())))
            #print('Anchor: %s' % (' AND '.join(exp.names())))
            f.write('Precision: %.2f\n' % exp.precision())
            f.write('Coverage: %.2f\n' % exp.coverage())
            f.write('\n')
            names.append(exp.names())
    
    dataframes.append(names)
    
    print(dataframes[i])
# Out:
# Train 0.9925
# Test 0.94
# [["b'firm obstacle' = 1.0", "b'image resolution' > 23.99", "b'smoke intensity' <= 49.24", "b'cruise speed' <= 71.28", "b'illuminance' > 27.51", "b'obstacle distance' <= 21.50"], ["b'firm obstacle' = 1.0", "b'image resolution' > 75.39", "b'cruise speed' <= 44.79", "b'illuminance' > 51.56"], ["b'firm obstacle' = 1.0", "b'image resolution' > 23.99", "b'illuminance' > 75.57", "b'cruise speed' <= 44.79", "b'power' > 23.00"], ["b'firm obstacle' = 1.0", "b'cruise speed' <= 22.33", "b'power' > 23.00", "b'smoke intensity' <= 74.25", "b'image resolution' > 23.99"], ["b'firm obstacle' = 1.0", "b'image resolution' > 75.39", "b'cruise speed' <= 44.79", "b'power' > 23.00", "b'obstacle distance' > 21.50"], ["b'firm obstacle' = 1.0", "b'smoke intensity' <= 23.26", "b'image resolution' > 51.33", "b'illuminance' > 27.51", "b'obstacle distance' > 43.80"], ["b'firm obstacle' = 1.0", "b'image resolution' > 75.39", "b'cruise speed' <= 44.79", "b'power' > 23.00", "b'smoke intensity' <= 74.25", "b'illuminance' > 27.51"], ["b'firm obstacle' = 1.0", "b'smoke intensity' <= 23.26", "b'cruise speed' <= 44.79", "b'illuminance' > 27.51", "b'image resolution' > 23.99"], ["b'firm obstacle' = 1.0", "b'smoke intensity' <= 23.26", "b'cruise speed' <= 71.28", "b'illuminance' > 27.51", "b'image resolution' > 23.99"], ["b'firm obstacle' = 1.0", "b'image resolution' > 51.33", "b'illuminance' > 75.57", "b'obstacle distance' > 43.80"], ["b'firm obstacle' = 1.0", "b'cruise speed' <= 22.33", "b'power' > 23.00", "b'smoke intensity' <= 74.25", "b'image resolution' > 23.99"], ["b'firm obstacle' = 1.0", "b'image resolution' > 51.33", "b'illuminance' > 75.57", "b'power' > 77.25"]]
# Train 0.995
# Test 0.86
# [["b'cruise speed' > 44.79", "b'firm obstacle' = 1.0"], ["b'cruise speed' <= 44.79", "b'smoke intensity' <= 49.24", "50.00 < b'power' <= 77.25", "51.56 < b'illuminance' <= 75.57", "b'obstacle size' > 71.67", "b'controls responsiveness' > 43.98", "b'image resolution' > 75.39", "b'obstacle distance' > 70.59"], ["b'illuminance' > 75.57", "b'controls responsiveness' > 74.46", "b'cruise speed' <= 44.79", "b'smoke intensity' <= 49.24", "b'power' > 23.00", "b'obstacle size' > 27.78", "23.99 < b'image resolution' <= 51.33", "b'obstacle distance' <= 70.59"], ["b'illuminance' > 51.56", "b'cruise speed' <= 22.33", "b'smoke intensity' <= 23.26", "b'power' > 77.25", "b'controls responsiveness' > 22.45", "b'obstacle size' > 49.35", "23.99 < b'image resolution' <= 51.33", "b'obstacle distance' <= 70.59"], ["27.78 < b'obstacle size' <= 49.35", "b'cruise speed' <= 44.79", "50.00 < b'power' <= 77.25", "27.51 < b'illuminance' <= 75.57", "b'controls responsiveness' > 74.46", "b'smoke intensity' <= 49.24", "b'image resolution' > 75.39", "21.50 < b'obstacle distance' <= 70.59"], ["b'smoke intensity' <= 23.26", "b'cruise speed' <= 44.79", "b'illuminance' > 27.51", "b'controls responsiveness' > 22.45", "b'power' > 23.00", "43.80 < b'obstacle distance' <= 70.59", "b'obstacle size' > 27.78", "23.99 < b'image resolution' <= 75.39"], ["b'illuminance' > 51.56", "b'cruise speed' <= 44.79", "b'controls responsiveness' > 22.45", "b'obstacle size' > 71.67", "b'power' > 77.25", "21.50 < b'obstacle distance' <= 70.59", "b'image resolution' > 23.99", "b'smoke intensity' <= 74.25"], ["b'smoke intensity' <= 23.26", "b'cruise speed' <= 44.79", "b'power' > 23.00", "b'controls responsiveness' > 74.46", "b'obstacle size' > 49.35", "b'illuminance' > 51.56", "23.99 < b'image resolution' <= 51.33", "43.80 < b'obstacle distance' <= 70.59"], ["b'power' > 23.00", "b'smoke intensity' <= 23.26", "b'cruise speed' <= 71.28", "b'controls responsiveness' > 22.45", "23.99 < b'image resolution' <= 51.33", "b'illuminance' > 75.57", "b'obstacle size' > 27.78", "21.50 < b'obstacle distance' <= 70.59"], ["b'image resolution' <= 75.39", "b'smoke intensity' > 49.24"], ["b'cruise speed' <= 22.33", "b'smoke intensity' <= 23.26", "50.00 < b'power' <= 77.25", "b'illuminance' > 75.57", "23.99 < b'image resolution' <= 51.33", "21.50 < b'obstacle distance' <= 70.59"], ["b'obstacle size' > 49.35", "b'cruise speed' <= 44.79", "b'power' > 77.25", "b'controls responsiveness' > 22.45", "23.99 < b'image resolution' <= 75.39", "b'smoke intensity' <= 49.24", "b'illuminance' > 75.57", "21.50 < b'obstacle distance' <= 43.80"]]
# Train 0.995
# Test 0.88
# [["b'firm obstacle' = 1.0", "b'controls responsiveness' > 74.46", "b'cruise speed' <= 71.28", "b'image resolution' > 23.99", "b'power' > 23.00", "b'illuminance' > 27.51", "b'smoke intensity' <= 49.24", "b'obstacle size' <= 71.67"], ["b'firm obstacle' = 1.0", "b'cruise speed' <= 44.79", "b'controls responsiveness' > 43.98", "b'image resolution' > 75.39", "b'illuminance' > 51.56", "b'obstacle distance' > 70.59"], ["b'firm obstacle' = 1.0", "b'illuminance' > 75.57", "b'cruise speed' <= 44.79", "b'controls responsiveness' > 43.98", "b'image resolution' > 23.99", "b'power' > 23.00"], ["b'firm obstacle' = 1.0", "b'cruise speed' <= 44.79", "b'controls responsiveness' > 43.98", "b'image resolution' > 23.99", "b'smoke intensity' <= 23.26", "b'illuminance' > 51.56", "b'power' > 77.25"], ["b'firm obstacle' = 1.0", "b'controls responsiveness' > 74.46", "b'cruise speed' <= 44.79", "b'image resolution' > 75.39", "b'illuminance' > 27.51", "b'smoke intensity' <= 49.24"], ["b'firm obstacle' = 1.0", "b'cruise speed' <= 44.79", "b'image resolution' > 51.33", "b'controls responsiveness' > 22.45", "b'smoke intensity' <= 23.26", "b'illuminance' > 27.51", "b'obstacle distance' > 21.50", "b'power' > 23.00"], ["b'firm obstacle' = 1.0", "b'cruise speed' <= 44.79", "b'image resolution' > 75.39", "b'controls responsiveness' > 22.45", "b'illuminance' > 51.56", "b'smoke intensity' <= 74.25"], ["b'firm obstacle' = 1.0", "b'cruise speed' <= 44.79", "b'controls responsiveness' > 74.46", "b'image resolution' > 23.99", "b'power' > 23.00", "b'illuminance' > 51.56", "b'smoke intensity' <= 23.26"], ["b'firm obstacle' = 1.0", "b'illuminance' > 75.57", "b'image resolution' > 23.99", "b'controls responsiveness' > 43.98", "b'cruise speed' <= 71.28", "b'power' > 23.00", "b'obstacle distance' > 21.50"], ["b'firm obstacle' = 1.0", "b'illuminance' > 75.57", "b'image resolution' > 23.99", "b'cruise speed' <= 44.79", "b'controls responsiveness' > 43.98", "b'power' > 23.00"], ["b'firm obstacle' = 1.0", "b'illuminance' > 75.57", "b'cruise speed' <= 22.33", "23.99 < b'image resolution' <= 51.33", "b'smoke intensity' <= 23.26", "21.50 < b'obstacle distance' <= 70.59", "b'obstacle size' <= 27.78", "b'power' > 50.00"], ["b'firm obstacle' = 1.0", "b'illuminance' > 75.57", "b'cruise speed' <= 44.79", "b'image resolution' > 51.33", "b'controls responsiveness' > 22.45", "b'power' > 23.00", "b'obstacle distance' > 21.50"]]
# Train 0.99
# Test 0.8
# [["b'firm obstacle' = 1.0", "b'controls responsiveness' > 74.46", "b'illuminance' > 27.51", "b'image resolution' > 23.99", "b'cruise speed' <= 71.28", "b'smoke intensity' <= 49.24", "27.78 < b'obstacle size' <= 71.67"], ["b'firm obstacle' = 1.0", "b'illuminance' > 51.56", "b'controls responsiveness' > 43.98", "b'image resolution' > 51.33", "b'obstacle distance' > 43.80"], ["b'firm obstacle' = 1.0", "b'controls responsiveness' > 74.46", "b'illuminance' > 51.56", "b'image resolution' > 23.99", "b'cruise speed' <= 71.28", "b'smoke intensity' <= 49.24"], ["b'firm obstacle' = 1.0", "b'illuminance' > 51.56", "b'controls responsiveness' > 43.98", "b'image resolution' > 23.99", "b'cruise speed' <= 22.33", "b'power' > 50.00", "b'smoke intensity' <= 23.26"], ["b'firm obstacle' = 1.0", "b'controls responsiveness' > 74.46", "b'illuminance' > 27.51", "b'image resolution' > 75.39", "b'cruise speed' <= 44.79", "b'obstacle distance' > 21.50"], ["b'firm obstacle' = 1.0", "b'cruise speed' <= 44.79", "b'image resolution' > 51.33", "b'controls responsiveness' > 22.45", "b'illuminance' > 27.51", "b'obstacle distance' > 21.50", "b'smoke intensity' <= 23.26"], ["b'firm obstacle' = 1.0", "b'illuminance' > 51.56", "b'cruise speed' <= 44.79", "b'image resolution' > 75.39", "b'controls responsiveness' > 22.45", "b'obstacle distance' > 21.50"], ["b'firm obstacle' = 1.0", "b'controls responsiveness' > 74.46", "b'illuminance' > 51.56", "b'image resolution' > 23.99", "b'cruise speed' <= 71.28", "b'obstacle size' <= 71.67"], ["b'firm obstacle' = 1.0", "b'illuminance' > 75.57", "b'controls responsiveness' > 43.98", "b'image resolution' > 23.99", "b'cruise speed' <= 71.28", "b'obstacle distance' > 21.50", "b'smoke intensity' <= 23.26"], ["b'firm obstacle' = 1.0", "b'illuminance' > 75.57", "b'controls responsiveness' > 43.98", "b'image resolution' > 51.33", "b'obstacle distance' > 43.80"], ["b'firm obstacle' = 1.0", "b'illuminance' > 75.57", "b'image resolution' > 23.99", "b'cruise speed' <= 44.79", "b'obstacle distance' > 21.50", "b'obstacle size' <= 49.35", "23.00 < b'power' <= 77.25"], ["b'firm obstacle' = 1.0", "b'illuminance' > 75.57", "b'image resolution' > 51.33", "b'controls responsiveness' > 22.45", "b'cruise speed' <= 71.28", "b'obstacle distance' > 21.50"]]

# %% [markdown]
# It prints the rules that allow us to keep the sample's prediction, in this case False for requirement 2, and the precision and coverage with which these rules hold
#
# The coverage tells us how much of the dataset we have explained with this rule.

# %%
lista = []
for i in range(df.shape[0]):
    dat = df.iloc[i]
    if((dat['firm obstacle'] == 1 and dat['power']>23.00 and dat['cruise speed']<=71.28 and dat['smoke intensity']<=49.24 and dat['image resolution']>23.99 and dat['obstacle distance']<=43.80)):
        lista.append(dat)
        print(dat['firm obstacle'], dat['power'], dat['cruise speed'], dat['smoke intensity'], dat['image resolution'], dat['obstacle distance'], dat['req_0'], dat['req_1'], dat['req_2'], dat['req_3'])

print(len(lista)-12)
# Out:
# 1.0 69.0 22.7995 32.0775 47.5676 18.952 True False False True
# 1.0 72.0 18.0329 9.0105 88.1242 14.3371 True False True True
# 1.0 88.0 47.0146 11.4562 55.1652 28.0682 True False True True
# 1.0 72.0 61.9286 35.0041 80.1206 34.0424 True False False False
# 1.0 38.0 50.9071 45.0738 33.397 15.681 True True True True
# 1.0 30.0 35.8364 46.5315 49.6464 7.3371 True True True True
# 1.0 46.0 29.8661 45.8727 50.6223 17.2824 True False True True
# 1.0 97.0 12.8875 0.9936 49.3559 13.2518 True True True True
# 1.0 54.0 0.8053 6.5258 82.9626 12.8178 False False False False
# 1.0 38.0 0.5755 22.1285 61.4105 37.1102 True True False True
# 1.0 77.0 25.9089 31.7312 93.6499 22.3561 True True True True
# 1.0 31.0 43.2555 21.008 25.6881 34.9979 True False True True
# 1.0 80.0 38.3862 26.5053 75.4232 11.7324 True False False True
# 1.0 89.0 27.4022 15.124 76.5957 16.5379 True False False False
# 1.0 56.0 27.8734 13.3137 48.469 18.1208 True False False False
# 1.0 51.0 69.8011 15.0281 81.2153 15.2147 True False True True
# 1.0 89.0 67.3884 14.8276 97.7112 24.3901 True False False False
# 1.0 77.0 46.1078 30.3211 34.4913 38.2166 True False False True
# 1.0 86.0 0.0571 36.7167 30.9564 31.8367 True False True True
# 1.0 76.0 29.9633 24.6914 24.3389 26.241 True False True True
# 1.0 61.0 66.7921 30.6624 40.9977 22.364 True True False True
# 1.0 26.0 18.1077 21.3254 34.6933 3.2455 True False False False
# 1.0 43.0 60.537 3.8644 33.5818 24.5258 True True True True
# 1.0 97.0 70.1853 48.4129 89.7439 17.6417 False False False False
# 1.0 38.0 44.502 33.2836 60.605 18.8826 True False False True
# 1.0 58.0 12.9419 19.5839 30.3257 39.4229 True True True True
# 1.0 95.0 37.3821 39.9764 71.3693 23.1465 True True True True
# 1.0 48.0 3.7825 23.2642 74.4159 13.9217 True False False False
# 1.0 84.0 38.5143 25.7712 98.0599 43.0643 True False True True
# 17

# %%
def get_anchor(a):
    quoted_part = a.split("'")[1]
    rest = a.replace(f"'{quoted_part}'", '').replace("b", '').strip()

    return quoted_part, rest

# %%
dictionaries =[]
for i in range(len(dataframes[0])):
    dictionaries.append([{}, {}, {}, {}])
    for j in range(4):
        for k in range(len(dataframes[j][i])):
            quoted, rest = get_anchor(dataframes[j][i][k])
            dictionaries[i][j][quoted] = rest

# %%
featureNames = ['cruise speed','image resolution','illuminance','controls responsiveness','power',
     'smoke intensity','obstacle size','obstacle distance','firm obstacle']

# %%
import re
from math import inf

def parse_range(expr: str):
    expr = expr.strip().replace(" ", "")
    
    patterns = [
        (r"^=(\-?\d+(\.\d+)?)$", 'equals'),
        (r"^(>=|>)\s*(-?\d+(\.\d+)?)$", 'lower'),
        (r"^(<=|<)\s*(-?\d+(\.\d+)?)$", 'upper'),
        (r"^(-?\d+(\.\d+)?)(<=|<){1,2}(<=|<)(-?\d+(\.\d+)?)$", 'between'),
        (r"^(-?\d+(\.\d+)?)(>=|>){1,2}(>=|>)(-?\d+(\.\d+)?)$", 'reverse_between'),
    ]
    
    for pattern, kind in patterns:
        match = re.match(pattern, expr)
        if match:
            if kind == 'equals':
                num = float(match.group(1))
                return (num, num, True, True)
            elif kind == 'lower':
                op, num = match.group(1), float(match.group(2))
                return (
                    num,
                    inf,
                    op == '>=',
                    False
                )
            elif kind == 'upper':
                op, num = match.group(1), float(match.group(2))
                return (
                    -inf,
                    num,
                    False,
                    op == '<='
                )
            elif kind == 'between':
                low = float(match.group(1))
                op1 = match.group(3)
                op2 = match.group(4)
                high = float(match.group(5))
                return (
                    low,
                    high,
                    op1 == '<=',
                    op2 == '<='
                )
            elif kind == 'reverse_between':
                high = float(match.group(1))
                op1 = match.group(3)
                op2 = match.group(4)
                low = float(match.group(5))
                return (
                    low,
                    high,
                    op2 == '>=',
                    op1 == '>='
                )

    raise ValueError(f"Unrecognized format: {expr}")

# %%
dictionaries =[]
for i in range(len(dataframes[0])):
    dictionaries.append([{}, {}, {}, {}])
    for j in range(4):
        for k in range(len(dataframes[j][i])):
            quoted, rest = get_anchor(dataframes[j][i][k])
            dictionaries[i][j][quoted] = parse_range(rest)

# %%
from typing import Optional, Tuple

def intersect(
    a: Tuple[float, float, bool, bool],
    b: Tuple[float, float, bool, bool]
) -> Optional[Tuple[float, float, bool, bool]]:
    
    a_low, a_high, a_li, a_ui = a
    b_low, b_high, b_li, b_ui = b

    # Compute max of lower bounds
    if a_low > b_low:
        low, li = a_low, a_li
    elif a_low < b_low:
        low, li = b_low, b_li
    else:
        low = a_low
        li = a_li and b_li

    # Compute min of upper bounds
    if a_high < b_high:
        high, ui = a_high, a_ui
    elif a_high > b_high:
        high, ui = b_high, b_ui
    else:
        high = a_high
        ui = a_ui and b_ui

    # Check for empty intersection
    if low > high:
        return None
    if low == high and not (li and ui):
        return None

    return (low, high, li, ui)

# %%
print(intersect((1, 5, True, False), (3, 7, True, True)))
# ➞ (3, 5, True, False)

print(intersect((1, 2, True, False), (2, 3, True, True)))
# ➞ None

print(intersect((0, 10, True, True), (10, 20, False, True)))
# ➞ (10, 10, True, False) ➞ None

print(intersect((3, 3, True, True), (3, 3, True, True)))
# ➞ (3, 3, True, True)

print(intersect((3, 5, True, True), (-2, 4, False, False)))
#➞ (3, 4, True, False)
# Out:
# (3, 5, True, False)
# None
# None
# (3, 3, True, True)
# (3, 4, True, False)

# %%
intersected = []

for i in range(len(dataframes[0])):

    intersected.append({})

    for j in range(3):
        for k in featureNames:
            if k not in dictionaries[i][j] or k not in dictionaries[i][j+1]:
                continue
            else:
                print(k)
                print(dictionaries[i][j][k])
                print(dictionaries[i][j+1][k])
                inter = intersect(dictionaries[i][j][k], dictionaries[i][j+1][k])
                if inter is not None:
                    intersected[i][k] = inter
                    print(inter)
                else:
                    raise ValueError(f"Unrecognized format: {dictionaries[i][j][k]} and {dictionaries[i][j+1][k]}")
# Out:
# cruise speed
# (-inf, 71.28, False, True)
# (44.79, inf, False, False)
# (44.79, 71.28, False, True)
# firm obstacle
# (1.0, 1.0, True, True)
# (1.0, 1.0, True, True)
# (1.0, 1.0, True, True)
# cruise speed
# (44.79, inf, False, False)
# (-inf, 71.28, False, True)
# (44.79, 71.28, False, True)
# firm obstacle
# (1.0, 1.0, True, True)
# (1.0, 1.0, True, True)
# (1.0, 1.0, True, True)
# cruise speed
# (-inf, 71.28, False, True)
# (-inf, 71.28, False, True)
# (-inf, 71.28, False, True)
# image resolution
# (23.99, inf, False, False)
# (23.99, inf, False, False)
# (23.99, inf, False, False)
# illuminance
# (27.51, inf, False, False)
# (27.51, inf, False, False)
# (27.51, inf, False, False)
# controls responsiveness
# (74.46, inf, False, False)
# (74.46, inf, False, False)
# (74.46, inf, False, False)
# smoke intensity
# (-inf, 49.24, False, True)
# (-inf, 49.24, False, True)
# (-inf, 49.24, False, True)
# obstacle size
# (-inf, 71.67, False, True)
# (27.78, 71.67, False, True)
# (27.78, 71.67, False, True)
# firm obstacle
# (1.0, 1.0, True, True)
# (1.0, 1.0, True, True)
# (1.0, 1.0, True, True)
# cruise speed
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# image resolution
# (75.39, inf, False, False)
# (75.39, inf, False, False)
# (75.39, inf, False, False)
# illuminance
# (51.56, inf, False, False)
# (51.56, 75.57, False, True)
# (51.56, 75.57, False, True)
# cruise speed
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# image resolution
# (75.39, inf, False, False)
# (75.39, inf, False, False)
# (75.39, inf, False, False)
# illuminance
# (51.56, 75.57, False, True)
# (51.56, inf, False, False)
# (51.56, 75.57, False, True)
# controls responsiveness
# (43.98, inf, False, False)
# (43.98, inf, False, False)
# (43.98, inf, False, False)
# obstacle distance
# (70.59, inf, False, False)
# (70.59, inf, False, False)
# (70.59, inf, False, False)
# image resolution
# (75.39, inf, False, False)
# (51.33, inf, False, False)
# (75.39, inf, False, False)
# illuminance
# (51.56, inf, False, False)
# (51.56, inf, False, False)
# (51.56, inf, False, False)
# controls responsiveness
# (43.98, inf, False, False)
# (43.98, inf, False, False)
# (43.98, inf, False, False)
# obstacle distance
# (70.59, inf, False, False)
# (43.8, inf, False, False)
# (70.59, inf, False, False)
# firm obstacle
# (1.0, 1.0, True, True)
# (1.0, 1.0, True, True)
# (1.0, 1.0, True, True)
# cruise speed
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# image resolution
# (23.99, inf, False, False)
# (23.99, 51.33, False, True)
# (23.99, 51.33, False, True)
# illuminance
# (75.57, inf, False, False)
# (75.57, inf, False, False)
# (75.57, inf, False, False)
# power
# (23.0, inf, False, False)
# (23.0, inf, False, False)
# (23.0, inf, False, False)
# cruise speed
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# image resolution
# (23.99, 51.33, False, True)
# (23.99, inf, False, False)
# (23.99, 51.33, False, True)
# illuminance
# (75.57, inf, False, False)
# (75.57, inf, False, False)
# (75.57, inf, False, False)
# controls responsiveness
# (74.46, inf, False, False)
# (43.98, inf, False, False)
# (74.46, inf, False, False)
# power
# (23.0, inf, False, False)
# (23.0, inf, False, False)
# (23.0, inf, False, False)
# cruise speed
# (-inf, 44.79, False, True)
# (-inf, 71.28, False, True)
# (-inf, 44.79, False, True)
# image resolution
# (23.99, inf, False, False)
# (23.99, inf, False, False)
# (23.99, inf, False, False)
# illuminance
# (75.57, inf, False, False)
# (51.56, inf, False, False)
# (75.57, inf, False, False)
# controls responsiveness
# (43.98, inf, False, False)
# (74.46, inf, False, False)
# (74.46, inf, False, False)
# firm obstacle
# (1.0, 1.0, True, True)
# (1.0, 1.0, True, True)
# (1.0, 1.0, True, True)
# cruise speed
# (-inf, 22.33, False, True)
# (-inf, 22.33, False, True)
# (-inf, 22.33, False, True)
# image resolution
# (23.99, inf, False, False)
# (23.99, 51.33, False, True)
# (23.99, 51.33, False, True)
# power
# (23.0, inf, False, False)
# (77.25, inf, False, False)
# (77.25, inf, False, False)
# smoke intensity
# (-inf, 74.25, False, True)
# (-inf, 23.26, False, True)
# (-inf, 23.26, False, True)
# cruise speed
# (-inf, 22.33, False, True)
# (-inf, 44.79, False, True)
# (-inf, 22.33, False, True)
# image resolution
# (23.99, 51.33, False, True)
# (23.99, inf, False, False)
# (23.99, 51.33, False, True)
# illuminance
# (51.56, inf, False, False)
# (51.56, inf, False, False)
# (51.56, inf, False, False)
# controls responsiveness
# (22.45, inf, False, False)
# (43.98, inf, False, False)
# (43.98, inf, False, False)
# power
# (77.25, inf, False, False)
# (77.25, inf, False, False)
# (77.25, inf, False, False)
# smoke intensity
# (-inf, 23.26, False, True)
# (-inf, 23.26, False, True)
# (-inf, 23.26, False, True)
# cruise speed
# (-inf, 44.79, False, True)
# (-inf, 22.33, False, True)
# (-inf, 22.33, False, True)
# image resolution
# (23.99, inf, False, False)
# (23.99, inf, False, False)
# (23.99, inf, False, False)
# illuminance
# (51.56, inf, False, False)
# (51.56, inf, False, False)
# (51.56, inf, False, False)
# controls responsiveness
# (43.98, inf, False, False)
# (43.98, inf, False, False)
# (43.98, inf, False, False)
# power
# (77.25, inf, False, False)
# (50.0, inf, False, False)
# (77.25, inf, False, False)
# smoke intensity
# (-inf, 23.26, False, True)
# (-inf, 23.26, False, True)
# (-inf, 23.26, False, True)
# firm obstacle
# (1.0, 1.0, True, True)
# (1.0, 1.0, True, True)
# (1.0, 1.0, True, True)
# cruise speed
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# image resolution
# (75.39, inf, False, False)
# (75.39, inf, False, False)
# (75.39, inf, False, False)
# power
# (23.0, inf, False, False)
# (50.0, 77.25, False, True)
# (50.0, 77.25, False, True)
# obstacle distance
# (21.5, inf, False, False)
# (21.5, 70.59, False, True)
# (21.5, 70.59, False, True)
# cruise speed
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# image resolution
# (75.39, inf, False, False)
# (75.39, inf, False, False)
# (75.39, inf, False, False)
# illuminance
# (27.51, 75.57, False, True)
# (27.51, inf, False, False)
# (27.51, 75.57, False, True)
# controls responsiveness
# (74.46, inf, False, False)
# (74.46, inf, False, False)
# (74.46, inf, False, False)
# smoke intensity
# (-inf, 49.24, False, True)
# (-inf, 49.24, False, True)
# (-inf, 49.24, False, True)
# cruise speed
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# image resolution
# (75.39, inf, False, False)
# (75.39, inf, False, False)
# (75.39, inf, False, False)
# illuminance
# (27.51, inf, False, False)
# (27.51, inf, False, False)
# (27.51, inf, False, False)
# controls responsiveness
# (74.46, inf, False, False)
# (74.46, inf, False, False)
# (74.46, inf, False, False)
# firm obstacle
# (1.0, 1.0, True, True)
# (1.0, 1.0, True, True)
# (1.0, 1.0, True, True)
# image resolution
# (51.33, inf, False, False)
# (23.99, 75.39, False, True)
# (51.33, 75.39, False, True)
# illuminance
# (27.51, inf, False, False)
# (27.51, inf, False, False)
# (27.51, inf, False, False)
# smoke intensity
# (-inf, 23.26, False, True)
# (-inf, 23.26, False, True)
# (-inf, 23.26, False, True)
# obstacle distance
# (43.8, inf, False, False)
# (43.8, 70.59, False, True)
# (43.8, 70.59, False, True)
# cruise speed
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# image resolution
# (23.99, 75.39, False, True)
# (51.33, inf, False, False)
# (51.33, 75.39, False, True)
# illuminance
# (27.51, inf, False, False)
# (27.51, inf, False, False)
# (27.51, inf, False, False)
# controls responsiveness
# (22.45, inf, False, False)
# (22.45, inf, False, False)
# (22.45, inf, False, False)
# power
# (23.0, inf, False, False)
# (23.0, inf, False, False)
# (23.0, inf, False, False)
# smoke intensity
# (-inf, 23.26, False, True)
# (-inf, 23.26, False, True)
# (-inf, 23.26, False, True)
# obstacle distance
# (43.8, 70.59, False, True)
# (21.5, inf, False, False)
# (43.8, 70.59, False, True)
# cruise speed
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# image resolution
# (51.33, inf, False, False)
# (51.33, inf, False, False)
# (51.33, inf, False, False)
# illuminance
# (27.51, inf, False, False)
# (27.51, inf, False, False)
# (27.51, inf, False, False)
# controls responsiveness
# (22.45, inf, False, False)
# (22.45, inf, False, False)
# (22.45, inf, False, False)
# smoke intensity
# (-inf, 23.26, False, True)
# (-inf, 23.26, False, True)
# (-inf, 23.26, False, True)
# obstacle distance
# (21.5, inf, False, False)
# (21.5, inf, False, False)
# (21.5, inf, False, False)
# firm obstacle
# (1.0, 1.0, True, True)
# (1.0, 1.0, True, True)
# (1.0, 1.0, True, True)
# cruise speed
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# image resolution
# (75.39, inf, False, False)
# (23.99, inf, False, False)
# (75.39, inf, False, False)
# illuminance
# (27.51, inf, False, False)
# (51.56, inf, False, False)
# (51.56, inf, False, False)
# power
# (23.0, inf, False, False)
# (77.25, inf, False, False)
# (77.25, inf, False, False)
# smoke intensity
# (-inf, 74.25, False, True)
# (-inf, 74.25, False, True)
# (-inf, 74.25, False, True)
# cruise speed
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# image resolution
# (23.99, inf, False, False)
# (75.39, inf, False, False)
# (75.39, inf, False, False)
# illuminance
# (51.56, inf, False, False)
# (51.56, inf, False, False)
# (51.56, inf, False, False)
# controls responsiveness
# (22.45, inf, False, False)
# (22.45, inf, False, False)
# (22.45, inf, False, False)
# smoke intensity
# (-inf, 74.25, False, True)
# (-inf, 74.25, False, True)
# (-inf, 74.25, False, True)
# cruise speed
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# image resolution
# (75.39, inf, False, False)
# (75.39, inf, False, False)
# (75.39, inf, False, False)
# illuminance
# (51.56, inf, False, False)
# (51.56, inf, False, False)
# (51.56, inf, False, False)
# controls responsiveness
# (22.45, inf, False, False)
# (22.45, inf, False, False)
# (22.45, inf, False, False)
# firm obstacle
# (1.0, 1.0, True, True)
# (1.0, 1.0, True, True)
# (1.0, 1.0, True, True)
# cruise speed
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# image resolution
# (23.99, inf, False, False)
# (23.99, 51.33, False, True)
# (23.99, 51.33, False, True)
# illuminance
# (27.51, inf, False, False)
# (51.56, inf, False, False)
# (51.56, inf, False, False)
# smoke intensity
# (-inf, 23.26, False, True)
# (-inf, 23.26, False, True)
# (-inf, 23.26, False, True)
# cruise speed
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# image resolution
# (23.99, 51.33, False, True)
# (23.99, inf, False, False)
# (23.99, 51.33, False, True)
# illuminance
# (51.56, inf, False, False)
# (51.56, inf, False, False)
# (51.56, inf, False, False)
# controls responsiveness
# (74.46, inf, False, False)
# (74.46, inf, False, False)
# (74.46, inf, False, False)
# power
# (23.0, inf, False, False)
# (23.0, inf, False, False)
# (23.0, inf, False, False)
# smoke intensity
# (-inf, 23.26, False, True)
# (-inf, 23.26, False, True)
# (-inf, 23.26, False, True)
# cruise speed
# (-inf, 44.79, False, True)
# (-inf, 71.28, False, True)
# (-inf, 44.79, False, True)
# image resolution
# (23.99, inf, False, False)
# (23.99, inf, False, False)
# (23.99, inf, False, False)
# illuminance
# (51.56, inf, False, False)
# (51.56, inf, False, False)
# (51.56, inf, False, False)
# controls responsiveness
# (74.46, inf, False, False)
# (74.46, inf, False, False)
# (74.46, inf, False, False)
# firm obstacle
# (1.0, 1.0, True, True)
# (1.0, 1.0, True, True)
# (1.0, 1.0, True, True)
# cruise speed
# (-inf, 71.28, False, True)
# (-inf, 71.28, False, True)
# (-inf, 71.28, False, True)
# image resolution
# (23.99, inf, False, False)
# (23.99, 51.33, False, True)
# (23.99, 51.33, False, True)
# illuminance
# (27.51, inf, False, False)
# (75.57, inf, False, False)
# (75.57, inf, False, False)
# smoke intensity
# (-inf, 23.26, False, True)
# (-inf, 23.26, False, True)
# (-inf, 23.26, False, True)
# cruise speed
# (-inf, 71.28, False, True)
# (-inf, 71.28, False, True)
# (-inf, 71.28, False, True)
# image resolution
# (23.99, 51.33, False, True)
# (23.99, inf, False, False)
# (23.99, 51.33, False, True)
# illuminance
# (75.57, inf, False, False)
# (75.57, inf, False, False)
# (75.57, inf, False, False)
# controls responsiveness
# (22.45, inf, False, False)
# (43.98, inf, False, False)
# (43.98, inf, False, False)
# power
# (23.0, inf, False, False)
# (23.0, inf, False, False)
# (23.0, inf, False, False)
# obstacle distance
# (21.5, 70.59, False, True)
# (21.5, inf, False, False)
# (21.5, 70.59, False, True)
# cruise speed
# (-inf, 71.28, False, True)
# (-inf, 71.28, False, True)
# (-inf, 71.28, False, True)
# image resolution
# (23.99, inf, False, False)
# (23.99, inf, False, False)
# (23.99, inf, False, False)
# illuminance
# (75.57, inf, False, False)
# (75.57, inf, False, False)
# (75.57, inf, False, False)
# controls responsiveness
# (43.98, inf, False, False)
# (43.98, inf, False, False)
# (43.98, inf, False, False)
# obstacle distance
# (21.5, inf, False, False)
# (21.5, inf, False, False)
# (21.5, inf, False, False)
# firm obstacle
# (1.0, 1.0, True, True)
# (1.0, 1.0, True, True)
# (1.0, 1.0, True, True)
# image resolution
# (51.33, inf, False, False)
# (-inf, 75.39, False, True)
# (51.33, 75.39, False, True)
# image resolution
# (-inf, 75.39, False, True)
# (23.99, inf, False, False)
# (23.99, 75.39, False, True)
# image resolution
# (23.99, inf, False, False)
# (51.33, inf, False, False)
# (51.33, inf, False, False)
# illuminance
# (75.57, inf, False, False)
# (75.57, inf, False, False)
# (75.57, inf, False, False)
# controls responsiveness
# (43.98, inf, False, False)
# (43.98, inf, False, False)
# (43.98, inf, False, False)
# firm obstacle
# (1.0, 1.0, True, True)
# (1.0, 1.0, True, True)
# (1.0, 1.0, True, True)
# cruise speed
# (-inf, 22.33, False, True)
# (-inf, 22.33, False, True)
# (-inf, 22.33, False, True)
# image resolution
# (23.99, inf, False, False)
# (23.99, 51.33, False, True)
# (23.99, 51.33, False, True)
# power
# (23.0, inf, False, False)
# (50.0, 77.25, False, True)
# (50.0, 77.25, False, True)
# smoke intensity
# (-inf, 74.25, False, True)
# (-inf, 23.26, False, True)
# (-inf, 23.26, False, True)
# cruise speed
# (-inf, 22.33, False, True)
# (-inf, 22.33, False, True)
# (-inf, 22.33, False, True)
# image resolution
# (23.99, 51.33, False, True)
# (23.99, 51.33, False, True)
# (23.99, 51.33, False, True)
# illuminance
# (75.57, inf, False, False)
# (75.57, inf, False, False)
# (75.57, inf, False, False)
# power
# (50.0, 77.25, False, True)
# (50.0, inf, False, False)
# (50.0, 77.25, False, True)
# smoke intensity
# (-inf, 23.26, False, True)
# (-inf, 23.26, False, True)
# (-inf, 23.26, False, True)
# obstacle distance
# (21.5, 70.59, False, True)
# (21.5, 70.59, False, True)
# (21.5, 70.59, False, True)
# cruise speed
# (-inf, 22.33, False, True)
# (-inf, 44.79, False, True)
# (-inf, 22.33, False, True)
# image resolution
# (23.99, 51.33, False, True)
# (23.99, inf, False, False)
# (23.99, 51.33, False, True)
# illuminance
# (75.57, inf, False, False)
# (75.57, inf, False, False)
# (75.57, inf, False, False)
# power
# (50.0, inf, False, False)
# (23.0, 77.25, False, True)
# (50.0, 77.25, False, True)
# obstacle size
# (-inf, 27.78, False, True)
# (-inf, 49.35, False, True)
# (-inf, 27.78, False, True)
# obstacle distance
# (21.5, 70.59, False, True)
# (21.5, inf, False, False)
# (21.5, 70.59, False, True)
# firm obstacle
# (1.0, 1.0, True, True)
# (1.0, 1.0, True, True)
# (1.0, 1.0, True, True)
# image resolution
# (51.33, inf, False, False)
# (23.99, 75.39, False, True)
# (51.33, 75.39, False, True)
# illuminance
# (75.57, inf, False, False)
# (75.57, inf, False, False)
# (75.57, inf, False, False)
# power
# (77.25, inf, False, False)
# (77.25, inf, False, False)
# (77.25, inf, False, False)
# cruise speed
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# (-inf, 44.79, False, True)
# image resolution
# (23.99, 75.39, False, True)
# (51.33, inf, False, False)
# (51.33, 75.39, False, True)
# illuminance
# (75.57, inf, False, False)
# (75.57, inf, False, False)
# (75.57, inf, False, False)
# controls responsiveness
# (22.45, inf, False, False)
# (22.45, inf, False, False)
# (22.45, inf, False, False)
# power
# (77.25, inf, False, False)
# (23.0, inf, False, False)
# (77.25, inf, False, False)
# obstacle distance
# (21.5, 43.8, False, True)
# (21.5, inf, False, False)
# (21.5, 43.8, False, True)
# cruise speed
# (-inf, 44.79, False, True)
# (-inf, 71.28, False, True)
# (-inf, 44.79, False, True)
# image resolution
# (51.33, inf, False, False)
# (51.33, inf, False, False)
# (51.33, inf, False, False)
# illuminance
# (75.57, inf, False, False)
# (75.57, inf, False, False)
# (75.57, inf, False, False)
# controls responsiveness
# (22.45, inf, False, False)
# (22.45, inf, False, False)
# (22.45, inf, False, False)
# obstacle distance
# (21.5, inf, False, False)
# (21.5, inf, False, False)
# (21.5, inf, False, False)
# firm obstacle
# (1.0, 1.0, True, True)
# (1.0, 1.0, True, True)
# (1.0, 1.0, True, True)

# %%
all_true_dataset, type(all_true_dataset), all_true_dataset.shape, all_true_dataset.columns
# Out:
# (     cruise speed  image resolution  illuminance  controls responsiveness  \
#  67        50.9071           33.3970      42.4174                  83.5993
#  68        42.5871           92.9370      57.2953                  49.8743
#  70        35.8364           49.6464      81.5615                  88.6837
#  76        12.8875           49.3559      58.1259                  62.4755
#  96        25.9089           93.6499      28.8524                  94.5842
#  108       36.9259           53.8403      47.8659                  32.2035
#  195       41.5747           85.1220      61.4060                  41.9737
#  222       37.8936           41.8950      68.6273                  93.5441
#  258       60.5370           33.5818      83.8188                  44.1427
#  328       37.1301           53.6653      89.3982                  51.2406
#  341       12.9419           30.3257      88.7688                  20.1834
#  393       37.3821           71.3693      94.4444                  27.0420
#
#       power  smoke intensity  obstacle size  obstacle distance  firm obstacle
#  67    38.0          45.0738        39.7296            15.6810            1.0
#  68    66.0          31.1562        91.6935            73.1713            1.0
#  70    30.0          46.5315        38.0818             7.3371            1.0
#  76    97.0           0.9936        52.4364            13.2518            1.0
#  96    77.0          31.7312        48.5371            22.3561            1.0
#  108   24.0          13.2223        40.5285            65.4238            1.0
#  195   91.0          59.8884        77.9643            39.5358            1.0
#  222   36.0           0.4611        65.6436            47.0799            1.0
#  258   43.0           3.8644        41.0958            24.5258            1.0
#  328   68.0          60.8477        76.3174            45.4778            1.0
#  341   58.0          19.5839         8.0412            39.4229            1.0
#  393   95.0          39.9764        62.9876            23.1465            1.0  ,
#  pandas.core.frame.DataFrame,
#  (12, 9),
#  Index(['cruise speed', 'image resolution', 'illuminance',
#         'controls responsiveness', 'power', 'smoke intensity', 'obstacle size',
#         'obstacle distance', 'firm obstacle'],
#        dtype='object'))

# %%
def inside(val, interval):
    low, high, li, ui = interval
    if li and ui:
        return low <= val <= high
    elif li and not ui:
        return low <= val < high
    elif not li and ui:
        return low < val <= high
    else:
        return low < val < high

# %%
sat = []
for i in range(all_true_dataset.shape[0]):
    for j in range(len(intersected)):
        flag = True
        for k in featureNames:
            if k not in intersected[j]:
                continue
            else:
                if not (inside(all_true_dataset.iloc[i][k], intersected[j][k])):
                    print(all_true_dataset.iloc[i])
                    flag = False
                    break
        
        if flag:
            sat.append(all_true_dataset.iloc[i])
            break
        else:
            flag = True
# Out:
# cruise speed               42.5871
# image resolution           92.9370
# illuminance                57.2953
# controls responsiveness    49.8743
# power                      66.0000
# smoke intensity            31.1562
# obstacle size              91.6935
# obstacle distance          73.1713
# firm obstacle               1.0000
# Name: 68, dtype: float64
# cruise speed               12.8875
# image resolution           49.3559
# illuminance                58.1259
# controls responsiveness    62.4755
# power                      97.0000
# smoke intensity             0.9936
# obstacle size              52.4364
# obstacle distance          13.2518
# firm obstacle               1.0000
# Name: 76, dtype: float64
# cruise speed               12.8875
# image resolution           49.3559
# illuminance                58.1259
# controls responsiveness    62.4755
# power                      97.0000
# smoke intensity             0.9936
# obstacle size              52.4364
# obstacle distance          13.2518
# firm obstacle               1.0000
# Name: 76, dtype: float64
# cruise speed               12.8875
# image resolution           49.3559
# illuminance                58.1259
# controls responsiveness    62.4755
# power                      97.0000
# smoke intensity             0.9936
# obstacle size              52.4364
# obstacle distance          13.2518
# firm obstacle               1.0000
# Name: 76, dtype: float64
# cruise speed               36.9259
# image resolution           53.8403
# illuminance                47.8659
# controls responsiveness    32.2035
# power                      24.0000
# smoke intensity            13.2223
# obstacle size              40.5285
# obstacle distance          65.4238
# firm obstacle               1.0000
# Name: 108, dtype: float64
# cruise speed               36.9259
# image resolution           53.8403
# illuminance                47.8659
# controls responsiveness    32.2035
# power                      24.0000
# smoke intensity            13.2223
# obstacle size              40.5285
# obstacle distance          65.4238
# firm obstacle               1.0000
# Name: 108, dtype: float64
# cruise speed               36.9259
# image resolution           53.8403
# illuminance                47.8659
# controls responsiveness    32.2035
# power                      24.0000
# smoke intensity            13.2223
# obstacle size              40.5285
# obstacle distance          65.4238
# firm obstacle               1.0000
# Name: 108, dtype: float64
# cruise speed               36.9259
# image resolution           53.8403
# illuminance                47.8659
# controls responsiveness    32.2035
# power                      24.0000
# smoke intensity            13.2223
# obstacle size              40.5285
# obstacle distance          65.4238
# firm obstacle               1.0000
# Name: 108, dtype: float64
# cruise speed               36.9259
# image resolution           53.8403
# illuminance                47.8659
# controls responsiveness    32.2035
# power                      24.0000
# smoke intensity            13.2223
# obstacle size              40.5285
# obstacle distance          65.4238
# firm obstacle               1.0000
# Name: 108, dtype: float64
# cruise speed               41.5747
# image resolution           85.1220
# illuminance                61.4060
# controls responsiveness    41.9737
# power                      91.0000
# smoke intensity            59.8884
# obstacle size              77.9643
# obstacle distance          39.5358
# firm obstacle               1.0000
# Name: 195, dtype: float64
# cruise speed               41.5747
# image resolution           85.1220
# illuminance                61.4060
# controls responsiveness    41.9737
# power                      91.0000
# smoke intensity            59.8884
# obstacle size              77.9643
# obstacle distance          39.5358
# firm obstacle               1.0000
# Name: 195, dtype: float64
# cruise speed               41.5747
# image resolution           85.1220
# illuminance                61.4060
# controls responsiveness    41.9737
# power                      91.0000
# smoke intensity            59.8884
# obstacle size              77.9643
# obstacle distance          39.5358
# firm obstacle               1.0000
# Name: 195, dtype: float64
# cruise speed               41.5747
# image resolution           85.1220
# illuminance                61.4060
# controls responsiveness    41.9737
# power                      91.0000
# smoke intensity            59.8884
# obstacle size              77.9643
# obstacle distance          39.5358
# firm obstacle               1.0000
# Name: 195, dtype: float64
# cruise speed               41.5747
# image resolution           85.1220
# illuminance                61.4060
# controls responsiveness    41.9737
# power                      91.0000
# smoke intensity            59.8884
# obstacle size              77.9643
# obstacle distance          39.5358
# firm obstacle               1.0000
# Name: 195, dtype: float64
# cruise speed               41.5747
# image resolution           85.1220
# illuminance                61.4060
# controls responsiveness    41.9737
# power                      91.0000
# smoke intensity            59.8884
# obstacle size              77.9643
# obstacle distance          39.5358
# firm obstacle               1.0000
# Name: 195, dtype: float64
# cruise speed               60.5370
# image resolution           33.5818
# illuminance                83.8188
# controls responsiveness    44.1427
# power                      43.0000
# smoke intensity             3.8644
# obstacle size              41.0958
# obstacle distance          24.5258
# firm obstacle               1.0000
# Name: 258, dtype: float64
# cruise speed               60.5370
# image resolution           33.5818
# illuminance                83.8188
# controls responsiveness    44.1427
# power                      43.0000
# smoke intensity             3.8644
# obstacle size              41.0958
# obstacle distance          24.5258
# firm obstacle               1.0000
# Name: 258, dtype: float64
# cruise speed               60.5370
# image resolution           33.5818
# illuminance                83.8188
# controls responsiveness    44.1427
# power                      43.0000
# smoke intensity             3.8644
# obstacle size              41.0958
# obstacle distance          24.5258
# firm obstacle               1.0000
# Name: 258, dtype: float64
# cruise speed               60.5370
# image resolution           33.5818
# illuminance                83.8188
# controls responsiveness    44.1427
# power                      43.0000
# smoke intensity             3.8644
# obstacle size              41.0958
# obstacle distance          24.5258
# firm obstacle               1.0000
# Name: 258, dtype: float64
# cruise speed               60.5370
# image resolution           33.5818
# illuminance                83.8188
# controls responsiveness    44.1427
# power                      43.0000
# smoke intensity             3.8644
# obstacle size              41.0958
# obstacle distance          24.5258
# firm obstacle               1.0000
# Name: 258, dtype: float64
# cruise speed               60.5370
# image resolution           33.5818
# illuminance                83.8188
# controls responsiveness    44.1427
# power                      43.0000
# smoke intensity             3.8644
# obstacle size              41.0958
# obstacle distance          24.5258
# firm obstacle               1.0000
# Name: 258, dtype: float64
# cruise speed               60.5370
# image resolution           33.5818
# illuminance                83.8188
# controls responsiveness    44.1427
# power                      43.0000
# smoke intensity             3.8644
# obstacle size              41.0958
# obstacle distance          24.5258
# firm obstacle               1.0000
# Name: 258, dtype: float64
# cruise speed               60.5370
# image resolution           33.5818
# illuminance                83.8188
# controls responsiveness    44.1427
# power                      43.0000
# smoke intensity             3.8644
# obstacle size              41.0958
# obstacle distance          24.5258
# firm obstacle               1.0000
# Name: 258, dtype: float64
# cruise speed               37.1301
# image resolution           53.6653
# illuminance                89.3982
# controls responsiveness    51.2406
# power                      68.0000
# smoke intensity            60.8477
# obstacle size              76.3174
# obstacle distance          45.4778
# firm obstacle               1.0000
# Name: 328, dtype: float64
# cruise speed               37.1301
# image resolution           53.6653
# illuminance                89.3982
# controls responsiveness    51.2406
# power                      68.0000
# smoke intensity            60.8477
# obstacle size              76.3174
# obstacle distance          45.4778
# firm obstacle               1.0000
# Name: 328, dtype: float64
# cruise speed               37.1301
# image resolution           53.6653
# illuminance                89.3982
# controls responsiveness    51.2406
# power                      68.0000
# smoke intensity            60.8477
# obstacle size              76.3174
# obstacle distance          45.4778
# firm obstacle               1.0000
# Name: 328, dtype: float64
# cruise speed               37.1301
# image resolution           53.6653
# illuminance                89.3982
# controls responsiveness    51.2406
# power                      68.0000
# smoke intensity            60.8477
# obstacle size              76.3174
# obstacle distance          45.4778
# firm obstacle               1.0000
# Name: 328, dtype: float64
# cruise speed               37.1301
# image resolution           53.6653
# illuminance                89.3982
# controls responsiveness    51.2406
# power                      68.0000
# smoke intensity            60.8477
# obstacle size              76.3174
# obstacle distance          45.4778
# firm obstacle               1.0000
# Name: 328, dtype: float64
# cruise speed               37.1301
# image resolution           53.6653
# illuminance                89.3982
# controls responsiveness    51.2406
# power                      68.0000
# smoke intensity            60.8477
# obstacle size              76.3174
# obstacle distance          45.4778
# firm obstacle               1.0000
# Name: 328, dtype: float64
# cruise speed               37.1301
# image resolution           53.6653
# illuminance                89.3982
# controls responsiveness    51.2406
# power                      68.0000
# smoke intensity            60.8477
# obstacle size              76.3174
# obstacle distance          45.4778
# firm obstacle               1.0000
# Name: 328, dtype: float64
# cruise speed               37.1301
# image resolution           53.6653
# illuminance                89.3982
# controls responsiveness    51.2406
# power                      68.0000
# smoke intensity            60.8477
# obstacle size              76.3174
# obstacle distance          45.4778
# firm obstacle               1.0000
# Name: 328, dtype: float64
# cruise speed               37.1301
# image resolution           53.6653
# illuminance                89.3982
# controls responsiveness    51.2406
# power                      68.0000
# smoke intensity            60.8477
# obstacle size              76.3174
# obstacle distance          45.4778
# firm obstacle               1.0000
# Name: 328, dtype: float64
# cruise speed               12.9419
# image resolution           30.3257
# illuminance                88.7688
# controls responsiveness    20.1834
# power                      58.0000
# smoke intensity            19.5839
# obstacle size               8.0412
# obstacle distance          39.4229
# firm obstacle               1.0000
# Name: 341, dtype: float64
# cruise speed               12.9419
# image resolution           30.3257
# illuminance                88.7688
# controls responsiveness    20.1834
# power                      58.0000
# smoke intensity            19.5839
# obstacle size               8.0412
# obstacle distance          39.4229
# firm obstacle               1.0000
# Name: 341, dtype: float64
# cruise speed               12.9419
# image resolution           30.3257
# illuminance                88.7688
# controls responsiveness    20.1834
# power                      58.0000
# smoke intensity            19.5839
# obstacle size               8.0412
# obstacle distance          39.4229
# firm obstacle               1.0000
# Name: 341, dtype: float64
# cruise speed               12.9419
# image resolution           30.3257
# illuminance                88.7688
# controls responsiveness    20.1834
# power                      58.0000
# smoke intensity            19.5839
# obstacle size               8.0412
# obstacle distance          39.4229
# firm obstacle               1.0000
# Name: 341, dtype: float64
# cruise speed               12.9419
# image resolution           30.3257
# illuminance                88.7688
# controls responsiveness    20.1834
# power                      58.0000
# smoke intensity            19.5839
# obstacle size               8.0412
# obstacle distance          39.4229
# firm obstacle               1.0000
# Name: 341, dtype: float64
# cruise speed               12.9419
# image resolution           30.3257
# illuminance                88.7688
# controls responsiveness    20.1834
# power                      58.0000
# smoke intensity            19.5839
# obstacle size               8.0412
# obstacle distance          39.4229
# firm obstacle               1.0000
# Name: 341, dtype: float64
# cruise speed               12.9419
# image resolution           30.3257
# illuminance                88.7688
# controls responsiveness    20.1834
# power                      58.0000
# smoke intensity            19.5839
# obstacle size               8.0412
# obstacle distance          39.4229
# firm obstacle               1.0000
# Name: 341, dtype: float64
# cruise speed               12.9419
# image resolution           30.3257
# illuminance                88.7688
# controls responsiveness    20.1834
# power                      58.0000
# smoke intensity            19.5839
# obstacle size               8.0412
# obstacle distance          39.4229
# firm obstacle               1.0000
# Name: 341, dtype: float64
# cruise speed               12.9419
# image resolution           30.3257
# illuminance                88.7688
# controls responsiveness    20.1834
# power                      58.0000
# smoke intensity            19.5839
# obstacle size               8.0412
# obstacle distance          39.4229
# firm obstacle               1.0000
# Name: 341, dtype: float64
# cruise speed               12.9419
# image resolution           30.3257
# illuminance                88.7688
# controls responsiveness    20.1834
# power                      58.0000
# smoke intensity            19.5839
# obstacle size               8.0412
# obstacle distance          39.4229
# firm obstacle               1.0000
# Name: 341, dtype: float64
# cruise speed               37.3821
# image resolution           71.3693
# illuminance                94.4444
# controls responsiveness    27.0420
# power                      95.0000
# smoke intensity            39.9764
# obstacle size              62.9876
# obstacle distance          23.1465
# firm obstacle               1.0000
# Name: 393, dtype: float64
# cruise speed               37.3821
# image resolution           71.3693
# illuminance                94.4444
# controls responsiveness    27.0420
# power                      95.0000
# smoke intensity            39.9764
# obstacle size              62.9876
# obstacle distance          23.1465
# firm obstacle               1.0000
# Name: 393, dtype: float64
# cruise speed               37.3821
# image resolution           71.3693
# illuminance                94.4444
# controls responsiveness    27.0420
# power                      95.0000
# smoke intensity            39.9764
# obstacle size              62.9876
# obstacle distance          23.1465
# firm obstacle               1.0000
# Name: 393, dtype: float64
# cruise speed               37.3821
# image resolution           71.3693
# illuminance                94.4444
# controls responsiveness    27.0420
# power                      95.0000
# smoke intensity            39.9764
# obstacle size              62.9876
# obstacle distance          23.1465
# firm obstacle               1.0000
# Name: 393, dtype: float64
# cruise speed               37.3821
# image resolution           71.3693
# illuminance                94.4444
# controls responsiveness    27.0420
# power                      95.0000
# smoke intensity            39.9764
# obstacle size              62.9876
# obstacle distance          23.1465
# firm obstacle               1.0000
# Name: 393, dtype: float64
# cruise speed               37.3821
# image resolution           71.3693
# illuminance                94.4444
# controls responsiveness    27.0420
# power                      95.0000
# smoke intensity            39.9764
# obstacle size              62.9876
# obstacle distance          23.1465
# firm obstacle               1.0000
# Name: 393, dtype: float64
# cruise speed               37.3821
# image resolution           71.3693
# illuminance                94.4444
# controls responsiveness    27.0420
# power                      95.0000
# smoke intensity            39.9764
# obstacle size              62.9876
# obstacle distance          23.1465
# firm obstacle               1.0000
# Name: 393, dtype: float64
# cruise speed               37.3821
# image resolution           71.3693
# illuminance                94.4444
# controls responsiveness    27.0420
# power                      95.0000
# smoke intensity            39.9764
# obstacle size              62.9876
# obstacle distance          23.1465
# firm obstacle               1.0000
# Name: 393, dtype: float64
# cruise speed               37.3821
# image resolution           71.3693
# illuminance                94.4444
# controls responsiveness    27.0420
# power                      95.0000
# smoke intensity            39.9764
# obstacle size              62.9876
# obstacle distance          23.1465
# firm obstacle               1.0000
# Name: 393, dtype: float64
# cruise speed               37.3821
# image resolution           71.3693
# illuminance                94.4444
# controls responsiveness    27.0420
# power                      95.0000
# smoke intensity            39.9764
# obstacle size              62.9876
# obstacle distance          23.1465
# firm obstacle               1.0000
# Name: 393, dtype: float64
# cruise speed               37.3821
# image resolution           71.3693
# illuminance                94.4444
# controls responsiveness    27.0420
# power                      95.0000
# smoke intensity            39.9764
# obstacle size              62.9876
# obstacle distance          23.1465
# firm obstacle               1.0000
# Name: 393, dtype: float64

# %%
print(len(sat))
# Out:
# 12

# %%
#get the features from the dataset5000.csv file
dataset5000 = pd.read_csv('../datasets/dataset5000.csv')
dataset5000 = dataset5000.drop(columns=['req_0','req_1', 'req_2', 'req_3'])
print(dataset5000.shape)
print(dataset5000.columns)
print(dataset5000.columns[0:9])
# Out:
# (5000, 9)
# Index(['cruise speed', 'image resolution', 'illuminance',
#        'controls responsiveness', 'power', 'smoke intensity', 'obstacle size',
#        'obstacle distance', 'firm obstacle'],
#       dtype='object')
# Index(['cruise speed', 'image resolution', 'illuminance',
#        'controls responsiveness', 'power', 'smoke intensity', 'obstacle size',
#        'obstacle distance', 'firm obstacle'],
#       dtype='object')

# %%
targets = np.zeros((dataset5000.shape[0], len(c)))
for i in range(dataset5000.shape[0]):
    for j in range(len(c)):
        targets[i,j] = c[j].predict(dataset5000.iloc[i].values.reshape(1, -1))

# %%
all_yes_t = np.all(targets==1, axis = 1)

# %%
dataset5000.iloc[all_yes_t]
# Out:
#       cruise speed  image resolution  illuminance  controls responsiveness  \
# 63         14.4434           56.6146      48.8867                  47.6686
# 345        34.9818           97.8935      45.3664                  46.4637
# 1023       33.9562           97.0994      43.2515                  53.6424
# 1062       48.6462           76.0222      98.6827                  82.4587
# 1544       42.2908           98.8765      37.9864                  83.2638
# 1637       22.5832           99.8643      84.0750                  39.7827
# 1883       67.5244           53.1727      99.2176                  73.0506
# 2071        6.7042           98.4822      95.2254                  71.1003
# 2575       35.6504           46.3007      96.2206                  33.7937
# 2611       27.5392           98.4133      76.1458                  97.6327
# 2729        1.0561           98.3725      59.0646                  65.1343
# 2926       32.7148           26.6316      78.3847                  61.1433
# 3003        0.6188           49.0217      94.2955                  33.3398
# 3074       38.1123           98.7240      52.3525                  62.0028
# 3076       57.4715           95.2820      72.1608                  76.4645
# 3408       22.9534           97.4496      98.9064                  70.6659
# 3556       10.6046           93.3501      97.5487                  69.9513
# 3611        9.8026           36.2964      49.5370                  64.2610
# 3926        0.0891           28.5058      48.6663                  69.0115
# 3968       31.1665           23.2129      99.8354                  68.4679
# 4159       66.1436           73.0272      98.9289                  94.5271
# 4422       36.3241           72.3444      80.8282                  26.9847
# 4532       34.0557           94.2448      26.2277                  96.5546
# 4863       15.3136           51.4678      81.2942                  56.1542
# 4899       34.9404           46.6588      67.9912                  33.0430
#
#       power  smoke intensity  obstacle size  obstacle distance  firm obstacle
# 63     28.0           0.1115        25.2163            38.9935            1.0
# 345    58.0          18.3719        86.3436            23.8942            1.0
# 1023   73.0          65.2284        69.3947            22.0421            1.0
# 1062   81.0          45.9548        78.2544            30.5223            1.0
# 1544   93.0          63.7922        35.8349            25.5043            1.0
# 1637   63.0          11.7562        51.3617            98.0069            1.0
# 1883   80.0           4.0896        58.5291            27.2271            1.0
# 2071   47.0          46.5347        92.2202            16.3082            1.0
# 2575   67.0          14.6945        45.4962            81.9985            1.0
# 2611   37.0          11.9699        67.4760            21.7884            1.0
# 2729   81.0          67.0108        47.0505            22.3209            1.0
# 2926   64.0           3.3185        57.6839            40.6676            1.0
# 3003   86.0          18.7601        36.5613            59.5314            1.0
# 3074   24.0           3.7939        40.2496            87.4510            1.0
# 3076   88.0          64.7386        44.0219            83.0553            1.0
# 3408   75.0          41.2243        11.6400            33.5876            1.0
# 3556   77.0           4.5231        56.1616            18.9470            1.0
# 3611   95.0           1.2837        85.4021            75.8757            1.0
# 3926   83.0          28.3731        40.1625            40.6838            1.0
# 3968   71.0          10.6160        39.8497            43.0514            1.0
# 4159   70.0           7.6871        49.2011            62.4234            1.0
# 4422   66.0          68.5593        57.0124            56.1807            1.0
# 4532   45.0          28.7938        82.9818            73.2392            1.0
# 4863   95.0          13.5719        15.9381             7.3835            1.0
# 4899   73.0           2.2796        89.1663            63.9227            1.0

# %%
# inside intersected there are the values of the thresholds
# inside dataset5000 there are the values of the features
# inside targets there are the predictions of the model
# inside all_yes_t there are the values of the predictions of the model for each row of the dataset5000
def classify_w_anchor(input, thresholds):
    inside_points = []

    featureNames = ['cruise speed','image resolution','illuminance','controls responsiveness','power',
     'smoke intensity','obstacle size','obstacle distance','firm obstacle']
    
    for i in range(input.shape[0]):
        for j in range(len(thresholds)):
            flag = True
            for k in featureNames:
                if k in thresholds[j]:
                    if not (inside(input.iloc[i][k], thresholds[j][k])):
                        flag = False
                        break
            if flag:
                inside_points.append(input.iloc[i])
                break
            else:
                flag = True
    return inside_points

# %%
true_4_anchors = classify_w_anchor(dataset5000, intersected)
print(len(true_4_anchors))
# Out:
# 288

# %%
check = classify_w_anchor(all_true_dataset, intersected)

# %%
len(check)
# Out:
# 12

# %%
# Get test examples where the anchor applies
#fit_anchor = np.where(np.all(new_dataset.test[:, exp.features()] == new_dataset.test[idx][exp.features()], axis=1))[0]
#print('Anchor test precision: %.2f' % (np.mean(c.predict(new_dataset.test[fit_anchor]) == c.predict(new_dataset.test[idx].reshape(1, -1)))))
#print('Anchor test coverage: %.2f' % (fit_anchor.shape[0] / float(new_dataset.test.shape[0])))
